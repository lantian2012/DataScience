# %%
import argparse
import json
import pprint
import sys
import urllib
import urllib2
import time
import datetime
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
MovieTable = pd.read_pickle('MovieTableKmeanLabeled.pkl')
DirectorTable = pd.read_pickle('DirectorTable_Pred.pkl')
ActorTable = pd.read_pickle('ActorTable_Pred.pkl')
GenreTable = pd.read_pickle('GenreTable.pkl')

# %%
MovieTable['log'] = np.log(MovieTable.BoxOffice)
MovieTable.head()
# Out:
#    Audience_rating                                               Cast  \
# 0               78  [{u'name': u'Arnold Schwarzenegger', u'charact...
# 1               78  [{u'name': u'Michael J. Fox', u'characters': [...
# 2               61  [{u'name': u'Tom Cruise', u'characters': [u'Co...
# 3               70  [{u'name': u'Bruce Willis', u'characters': [u'...
# 4               67  [{u'name': u'Emilio Estevez', u'characters': [...
#
#    Critic_rating                         Director  \
# 0             84   [{u'name': u'Paul Verhoeven'}]
# 1             73  [{u'name': u'Robert Zemeckis'}]
# 2             39       [{u'name': u'Tony Scott'}]
# 3             66     [{u'name': u'Renny Harlin'}]
# 4             35     [{u'name': u'Geoff Murphy'}]
#
#                                                Genre     ID  \
# 0  [Action & Adventure, Mystery & Suspense, Scien...  16681
# 1  [Action & Adventure, Science Fiction & Fantasy...  23534
# 2               [Drama, Action & Adventure, Romance]  10704
# 3           [Mystery & Suspense, Action & Adventure]  16789
# 4                      [Western, Action & Adventure]  10544
#
#                          Movie     Release  \
# 0                 Total Recall  1990-06-01
# 1  Back to the Future Part III  1990-05-25
# 2              Days of Thunder  1990-06-27
# 3                   Die Hard 2  1990-07-02
# 4                Young Guns II  1990-08-01
#
#                                               Review     imdb  \
# 0  http://api.rottentomatoes.com/api/public/v1.0/...  0100802
# 1  http://api.rottentomatoes.com/api/public/v1.0/...  0099088
# 2  http://api.rottentomatoes.com/api/public/v1.0/...  0099371
# 3  http://api.rottentomatoes.com/api/public/v1.0/...  0099423
# 4  http://api.rottentomatoes.com/api/public/v1.0/...  0100994
#
#                                              weblink  BoxOffice ReleaseYear  \
# 0      http://www.rottentomatoes.com/m/total_recall/    8038759        1990
# 1  http://www.rottentomatoes.com/m/back_to_the_fu...   23703060        1990
# 2   http://www.rottentomatoes.com/m/days_of_thunder/   40000000        1990
# 3   http://www.rottentomatoes.com/m/die_hard_2_1990/  115288665        1990
# 4      http://www.rottentomatoes.com/m/young_guns_2/   19700000        1990
#
#    Label        log
# 0      1  15.899785
# 1      2  16.981115
# 2      2  17.504390
# 3      1  18.562950
# 4      1  16.796129

# %%
DirectorTable.head()
# Out:
#                 Name                                              Movie  \
# 0        Zack Snyder  [17051, 344023668, 770671949, 770805422, 77067...
# 1        Yimou Zhang                                        [771224622]
# 2        Woody Allen  [11130, 13381, 13502, 13690, 24478, 248007453,...
# 3  Wolfgang Petersen            [16314, 13283, 16823, 12890, 155654957]
# 4   William Friedkin        [14519, 13191, 13646, 368451322, 771210952]
#
#                               Critic_rating  \
# 0                      [75, 60, 65, 23, 55]
# 1                                      [41]
# 2  [93, 96, 77, 71, 76, 39, 81, 93, 43, 91]
# 3                      [95, 59, 79, 54, 33]
# 4                      [15, 36, 29, 61, 78]
#
#                             Audience_rating  \
# 0                      [77, 89, 70, 47, 76]
# 1                                      [74]
# 2  [84, 83, 74, 83, 81, 56, 74, 82, 40, 77]
# 3                      [79, 56, 66, 74, 44]
# 4                      [28, 55, 47, 34, 61]
#
#                                                Genre  \
# 0  [[Drama, Horror, Mystery & Suspense], [Drama, ...
# 1  [[Drama, Art House & International, Special In...
# 2  [[Mystery & Suspense, Comedy], [Comedy], [Come...
# 3  [[Mystery & Suspense, Action & Adventure], [Dr...
# 4  [[Drama, Action & Adventure, Mystery & Suspens...
#
#                                            Boxoffice  \
# 0  [58885635, 210515491, 107509799, 36392502, 291...
# 1                                           [311434]
# 2  [11285588, 13383737, 6700000, 10569071, 230899...
# 3  [102314283, 67823573, 172650002, 133378256, 60...
# 4    [9795017, 61322858, 34238611, 7006708, 1987762]
#
#                                          ReleaseYear  Critic_rating_AVG  \
# 0                     [2004, 2007, 2009, 2011, 2013]               55.6
# 1                                             [2011]               41.0
# 2  [1993, 1994, 1995, 1997, 2005, 2006, 2008, 201...               76.0
# 3                     [1993, 1995, 1997, 2004, 2006]               64.0
# 4                     [1995, 2000, 2003, 2006, 2012]               43.8
#
#    Audience_rating_AVG  Boxoffice_AVG  Count  Boxoffice_Sum
# 0                 71.8    140869789.0      5      704348945
# 1                 74.0       311434.0      1         311434
# 2                 73.4     20567350.1     10      205673501
# 3                 63.8    107368186.2      5      536840931
# 4                 45.0     22870191.2      5      114350956

# %%
ActorTable.head()
# Out:
#           ID                       Name  \
# 0  771513497             Madeline Stowe
# 1  771495090              Alison Janney
# 2  771410621         Chloe Grace Moretz
# 3  771395445               Jim Caviezel
# 4  770893686  Dwayne "The Rock" Johnson
#
#                                                Movie  \
# 0                [14256, 13792, 15508, 16619, 12912]
# 1  [13634, 10726, 12878, 11671, 9377, 460339382, ...
# 2  [770801801, 770786150, 770805260, 771041418, 7...
# 3            [15744, 10754, 10119, 10118, 771269520]
# 4  [11549, 10616, 10644, 8839, 178779288, 2878651...
#
#                                        Critic_rating  \
# 0                                [75, 9, 88, 22, 63]
# 1                       [84, 36, 88, 81, 99, 91, 94]
# 2                       [86, 76, 88, 94, 37, 29, 49]
# 3                               [79, 70, 40, 73, 48]
# 4  [41, 71, 25, 19, 36, 42, 28, 51, 43, 43, 77, 2...
#
#                                      Audience_rating  \
# 0                               [48, 41, 88, 46, 84]
# 1                       [83, 36, 93, 85, 86, 85, 88]
# 2                       [84, 81, 76, 78, 46, 59, 45]
# 3                               [80, 81, 78, 88, 56]
# 4  [38, 67, 60, 34, 41, 81, 70, 67, 44, 49, 82, 4...
#
#                                                Genre  \
# 0  [[Drama, Action & Adventure, Mystery & Suspens...
# 1  [[Drama], [Drama, Action & Adventure, Romance,...
# 2  [[Drama, Romance, Comedy], [Drama, Action & Ad...
# 3  [[Drama, Action & Adventure], [Drama, Action &...
# 4  [[Action & Adventure, Horror, Science Fiction ...
#
#                                            Boxoffice  Tweet  Follower  \
# 0  [26357000, 3038499, 15240435, 57141459, 395621...   1588      2845
# 1  [7837632, 74329966, 130058047, 41675994, 33971...    370     76263
# 2  [32391374, 48043505, 12134420, 45282, 73820094...  18272   1326244
# 3  [36385763, 44983704, 33508922, 54234062, 37078...      2     17733
# 4  [90341670, 47592825, 45860039, 28031250, 27538...   8637   7895563
#
#                                          ReleaseYear  \
# 0                     [1992, 1994, 1995, 1999, 2002]
# 1         [1997, 1998, 1999, 2002, 2003, 2007, 2007]
# 2         [2009, 2010, 2010, 2011, 2012, 2013, 2013]
# 3                     [1998, 2000, 2000, 2002, 2013]
# 4  [2002, 2003, 2004, 2005, 2007, 2006, 2007, 200...
#
#                                            BoxOffice  Critic_rating_AVG  \
# 0  [26357000, 15240435, 57141459, 102678089, 7812...          51.400000
# 1  [7837632, 74329966, 130058047, 41675994, 33971...          81.857143
# 2  [32391374, 48043505, 12134420, 73820094, 79711...          65.571429
# 3  [36385763, 44983704, 33508922, 54234062, 24610...          62.000000
# 4  [90341670, 47592825, 45860039, 28031250, 27538...          44.000000
#
#    Audience_rating_AVG    Boxoffice_AVG  Count  Boxoffice_Sum
# 0            61.400000  40933127.142857      5      286531890
# 1            79.428571  95230060.363636      7     1047530664
# 2            67.000000  38617383.500000      7      308939068
# 3            76.600000  56609009.900000      5      566090099
# 4            58.923077  82606637.562500     13     1321706201

# %%
GenreTable.head()
# Out:
#                        Genre  \
# 0         Action & Adventure
# 1         Mystery & Suspense
# 2  Science Fiction & Fantasy
# 3                     Comedy
# 4                      Drama
#
#                                                   ID  \
# 0  [16681, 23534, 10704, 16789, 10544, 16857, 162...
# 1  [16681, 16789, 16723, 11047, 13179, 13210, 163...
# 2  [16681, 23534, 16723, 11047, 16857, 15441, 100...
# 3  [23534, 11047, 13179, 16281, 12438, 12749, 146...
# 4  [10704, 13179, 13210, 16942, 16322, 13476, 100...
#
#                                      Audience_rating  \
# 0  [78, 78, 61, 70, 67, 58, 35, 44, 81, 51, 78, 5...
# 1  [78, 70, 60, 52, 81, 85, 89, 51, 95, 75, 65, 7...
# 2  [78, 78, 60, 52, 58, 44, 91, 94, 65, 23, 66, 6...
# 3  [78, 52, 81, 35, 79, 51, 27, 53, 50, 47, 66, 6...
# 4  [61, 81, 85, 81, 89, 78, 91, 89, 59, 75, 65, 8...
#
#                                        Critic_rating  \
# 0  [84, 73, 39, 66, 35, 82, 13, 25, 50, 51, 67, 7...
# 1  [84, 66, 48, 91, 64, 69, 89, 51, 94, 71, 61, 7...
# 2  [84, 73, 48, 91, 82, 25, 91, 92, 61, 0, 60, 0,...
# 3  [73, 91, 64, 13, 54, 51, 16, 74, 74, 33, 60, 0...
# 4  [39, 64, 69, 50, 89, 67, 91, 88, 24, 71, 61, 7...
#
#                                          ReleaseYear  \
# 0  [1990, 1990, 1990, 1990, 1990, 1990, 1990, 199...
# 1  [1990, 1990, 1990, 1990, 1990, 1990, 1990, 199...
# 2  [1990, 1990, 1990, 1990, 1990, 1990, 1990, 199...
# 3  [1990, 1990, 1990, 1990, 1990, 1990, 1990, 199...
# 4  [1990, 1990, 1990, 1990, 1990, 1990, 1990, 199...
#
#                                            BoxOffice  Count  BoxOfficeAvg
# 0  [8038759, 23703060, 40000000, 115288665, 19700...    681  8.330445e+07
# 1  [8038759, 115288665, 28800000, 31366000, 14560...    542  5.634911e+07
# 2  [8038759, 23703060, 28800000, 31366000, 329427...    332  1.039076e+08
# 3  [23703060, 31366000, 14560247, 31053601, 28149...    777  5.952983e+07
# 4  [40000000, 14560247, 26118851, 2075084, 268800...   1088  4.361672e+07

# %% [markdown]
# ### Put all information needed for regression into the MovieTable dataframe

# %%
MovieTable['Director_BoxOffice'] = range(len(MovieTable))
MovieTable['Director_BoxOffice_Sum'] = range(len(MovieTable))
MovieTable['Director_CR'] = range(len(MovieTable))
MovieTable['Director_AR'] = range(len(MovieTable))
MovieTable['Director_Count'] = range(len(MovieTable))
for i in range(len(MovieTable)):
    boxoffice = 0
    cr = 0
    ar = 0
    count = 0
    boxoffice_sum = 0
    for director in MovieTable.Director[i]:
        if DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_AVG'].values[0]>boxoffice:
            boxoffice = DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_AVG'].values[0]
        if DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_Sum'].values[0]>boxoffice_sum:
            boxoffice_sum = DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_Sum'].values[0]
        if DirectorTable[DirectorTable.Name==director['name']]['Critic_rating_AVG'].values[0]>cr:
            cr = DirectorTable[DirectorTable.Name==director['name']]['Critic_rating_AVG'].values[0]
        if DirectorTable[DirectorTable.Name==director['name']]['Audience_rating_AVG'].values[0]>ar:
            ar = DirectorTable[DirectorTable.Name==director['name']]['Audience_rating_AVG'].values[0]
        if DirectorTable[DirectorTable.Name==director['name']]['Count'].values[0]>count:
            count =DirectorTable[DirectorTable.Name==director['name']]['Count'].values[0]
    MovieTable.Director_BoxOffice[i] = boxoffice
    MovieTable.Director_CR[i] = cr
    MovieTable.Director_AR[i] = ar
    MovieTable.Director_Count[i] = count
    MovieTable.Director_BoxOffice_Sum[i] = boxoffice_sum

# %%
MovieTable['Actor_BoxOffice'] = range(len(MovieTable))
MovieTable['Actor_BoxOffice_Sum'] = range(len(MovieTable))
MovieTable['Actor_CR'] = range(len(MovieTable))
MovieTable['Actor_AR'] = range(len(MovieTable))
MovieTable['Actor_Count'] = range(len(MovieTable))
for i in range(len(MovieTable)):
    boxoffice = 0
    boxoffice_sum = 0
    cr = 0
    ar = 0
    count = 0
    for actor in MovieTable.Cast[i]:
        boxoffice = boxoffice + ActorTable[ActorTable.ID==actor['id']]['Boxoffice_AVG'].values[0]
        boxoffice_sum = boxoffice_sum + ActorTable[ActorTable.ID==actor['id']]['Boxoffice_Sum'].values[0]
        cr = cr + ActorTable[ActorTable.ID==actor['id']]['Critic_rating_AVG'].values[0]
        ar = ar + ActorTable[ActorTable.ID==actor['id']]['Audience_rating_AVG'].values[0]
        count = count + ActorTable[ActorTable.ID==actor['id']]['Count'].values[0]
    MovieTable.Actor_BoxOffice[i] = boxoffice
    MovieTable.Actor_BoxOffice_Sum[i] = boxoffice_sum
    MovieTable.Actor_CR[i] = cr
    MovieTable.Actor_AR[i] = ar
    MovieTable.Actor_Count[i] = count

# %%
MovieTable['Genre_BoxOffice'] = range(len(MovieTable))
for i in range(len(MovieTable)):
    boxoffice = 0
    for genre in MovieTable.Genre[i]:
        boxoffice = boxoffice + GenreTable[GenreTable.Genre==genre]['BoxOfficeAvg'].values[0]
    MovieTable.Genre_BoxOffice[i] = boxoffice/len(MovieTable.Genre[i])

# %%
MovieTable['ReleaseMonth'] = [float(i.split('-')[1]) for i in MovieTable.Release]

# %%
MovieTable.ReleaseYear = MovieTable.ReleaseYear.apply(float)

# %%
MovieTable.Label = MovieTable.Label.apply(str)

# %% [markdown]
# ###Multiple Linear Regression
# The variables were chosen mannually by determine the decrease in adj. r-squared after dropping a variable.

# %%
reg = smf.ols(formula='log~Audience_rating+Critic_rating+Director_BoxOffice+Director_BoxOffice_Sum+Director_Count+Director_CR+Genre_BoxOffice+Actor_BoxOffice_Sum+ReleaseYear', data=MovieTable).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    log   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.428
# Method:                 Least Squares   F-statistic:                     160.6
# Date:                Sun, 07 Dec 2014   Prob (F-statistic):          3.17e-226
# Time:                        17:59:07   Log-Likelihood:                -3473.8
# No. Observations:                1918   AIC:                             6968.
# Df Residuals:                    1908   BIC:                             7023.
# Df Model:                           9
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                  8.9203     11.832      0.754      0.451       -14.286    32.126
# Audience_rating            0.0172      0.003      6.394      0.000         0.012     0.022
# Critic_rating              0.0032      0.002      1.342      0.180        -0.001     0.008
# Director_BoxOffice      1.864e-08   1.19e-09     15.654      0.000      1.63e-08   2.1e-08
# Director_BoxOffice_Sum -1.431e-09   2.28e-10     -6.284      0.000     -1.88e-09 -9.84e-10
# Director_Count             0.1917      0.022      8.708      0.000         0.149     0.235
# Director_CR               -0.0204      0.003     -7.527      0.000        -0.026    -0.015
# Genre_BoxOffice         2.791e-08   2.43e-09     11.468      0.000      2.31e-08  3.27e-08
# Actor_BoxOffice_Sum     2.212e-10   2.49e-11      8.887      0.000      1.72e-10   2.7e-10
# ReleaseYear                0.0021      0.006      0.349      0.727        -0.010     0.014
# ==============================================================================
# Omnibus:                      684.564   Durbin-Watson:                   1.615
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2558.198
# Skew:                          -1.738   Prob(JB):                         0.00
# Kurtosis:                       7.464   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is -1.24e+06. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Test the regression result with movies in 2014

# %%
TestMovieTable = pd.read_pickle('MovieTable2014.pkl')
TestMovieTable.head()
# Out:
#    Audience_rating                                               Cast  \
# 0               60  [{u'name': u'Ice Cube', u'characters': [u'Jame...
# 1               36  [{u'name': u'Eddie Fernandez', u'id': u'770716...
# 2               39  [{u'name': u'Aaron Eckhart', u'characters': [u...
# 3               54  [{u'name': u'Chris Pine', u'characters': [u'Ja...
# 4               21  [{u'name': u'Allison Miller', u'characters': [...
#
#    Critic_rating                                           Director  \
# 0             17                          [{u'name': u'Tim Story'}]
# 1             38                 [{u'name': u'Christopher Landon'}]
# 2              3                     [{u'name': u'Stuart Beattie'}]
# 3             56                    [{u'name': u'Kenneth Branagh'}]
# 4             18  [{u'name': u'Radio Silence'}, {u'name': u'Matt...
#
#                                                Genre         ID  \
# 0                       [Action & Adventure, Comedy]  771320491
# 1                                           [Horror]  771364044
# 2  [Horror, Mystery & Suspense, Science Fiction &...  771257268
# 3    [Drama, Action & Adventure, Mystery & Suspense]  771314857
# 4                                           [Horror]  771355830
#
#                                   Movie     Release  \
# 0                            Ride Along  2014-01-17
# 1  Paranormal Activity: The Marked Ones  2014-01-03
# 2                       I, Frankenstein  2014-01-24
# 3             Jack Ryan: Shadow Recruit  2014-01-17
# 4                           Devil's Due  2014-01-17
#
#                                               Review     imdb  \
# 0  http://api.rottentomatoes.com/api/public/v1.0/...  1408253
# 1  http://api.rottentomatoes.com/api/public/v1.0/...  2473682
# 2  http://api.rottentomatoes.com/api/public/v1.0/...  1418377
# 3  http://api.rottentomatoes.com/api/public/v1.0/...  1205537
# 4  http://api.rottentomatoes.com/api/public/v1.0/...  2752758
#
#                                              weblink  BoxOffice
# 0   http://www.rottentomatoes.com/m/ride_along_2014/  134141530
# 1  http://www.rottentomatoes.com/m/paranormal_act...   32453345
# 2    http://www.rottentomatoes.com/m/i_frankenstein/   19059018
# 3  http://www.rottentomatoes.com/m/jack_ryan_shad...   50549107
# 4        http://www.rottentomatoes.com/m/devils_due/   15818967

# %%
len(DirectorTable[DirectorTable.Name=='tian'])
# Out:
# 0

# %% [markdown]
# ####Wrangle data to put all information into MovieTable

# %%
TestMovieTable['Director_BoxOffice'] = range(len(TestMovieTable))
TestMovieTable['Director_BoxOffice_Sum'] = range(len(TestMovieTable))
TestMovieTable['Director_CR'] = range(len(TestMovieTable))
TestMovieTable['Director_AR'] = range(len(TestMovieTable))
TestMovieTable['Director_Count'] = range(len(TestMovieTable))
for i in range(len(TestMovieTable)):
    boxoffice = 0
    cr = 0
    ar = 0
    count = 0
    boxoffice_sum = 0
    for director in TestMovieTable.Director[i]:
        if len(DirectorTable[DirectorTable.Name==director['name']])>0:
            if DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_AVG'].values[0]>boxoffice:
                boxoffice = DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_AVG'].values[0]
            if DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_Sum'].values[0]>boxoffice_sum:
                boxoffice_sum = DirectorTable[DirectorTable.Name==director['name']]['Boxoffice_Sum'].values[0]
            if DirectorTable[DirectorTable.Name==director['name']]['Critic_rating_AVG'].values[0]>cr:
                cr = DirectorTable[DirectorTable.Name==director['name']]['Critic_rating_AVG'].values[0]
            if DirectorTable[DirectorTable.Name==director['name']]['Audience_rating_AVG'].values[0]>ar:
                ar = DirectorTable[DirectorTable.Name==director['name']]['Audience_rating_AVG'].values[0]
            if DirectorTable[DirectorTable.Name==director['name']]['Count'].values[0]>count:
                count =DirectorTable[DirectorTable.Name==director['name']]['Count'].values[0]
    TestMovieTable.Director_BoxOffice[i] = boxoffice
    TestMovieTable.Director_CR[i] = cr
    TestMovieTable.Director_AR[i] = ar
    TestMovieTable.Director_Count[i] = count
    TestMovieTable.Director_BoxOffice_Sum[i] = boxoffice_sum

# %%
TestMovieTable['Actor_BoxOffice'] = range(len(TestMovieTable))
TestMovieTable['Actor_BoxOffice_Sum'] = range(len(TestMovieTable))
TestMovieTable['Actor_CR'] = range(len(TestMovieTable))
TestMovieTable['Actor_AR'] = range(len(TestMovieTable))
TestMovieTable['Actor_Count'] = range(len(TestMovieTable))
for i in range(len(TestMovieTable)):
    boxoffice = 0
    boxoffice_sum = 0
    cr = 0
    ar = 0
    count = 0
    for actor in TestMovieTable.Cast[i]:
        if len(ActorTable[ActorTable.ID==actor['id']])>0:
            boxoffice = boxoffice + ActorTable[ActorTable.ID==actor['id']]['Boxoffice_AVG'].values[0]
            boxoffice_sum = boxoffice_sum + ActorTable[ActorTable.ID==actor['id']]['Boxoffice_Sum'].values[0]
            cr = cr + ActorTable[ActorTable.ID==actor['id']]['Critic_rating_AVG'].values[0]
            ar = ar + ActorTable[ActorTable.ID==actor['id']]['Audience_rating_AVG'].values[0]
            count = count + ActorTable[ActorTable.ID==actor['id']]['Count'].values[0]
    TestMovieTable.Actor_BoxOffice[i] = boxoffice
    TestMovieTable.Actor_BoxOffice_Sum[i] = boxoffice_sum
    TestMovieTable.Actor_CR[i] = cr
    TestMovieTable.Actor_AR[i] = ar
    TestMovieTable.Actor_Count[i] = count

# %%
TestMovieTable['Genre_BoxOffice'] = range(len(TestMovieTable))
for i in range(len(TestMovieTable)):
    boxoffice = 0
    for genre in TestMovieTable.Genre[i]:
        boxoffice = boxoffice + GenreTable[GenreTable.Genre==genre]['BoxOfficeAvg'].values[0]
    TestMovieTable.Genre_BoxOffice[i] = boxoffice/len(TestMovieTable.Genre[i])

# %%
TestMovieTable['ReleaseMonth'] = [float(i.split('-')[1]) for i in TestMovieTable.Release]
TestMovieTable['ReleaseYear'] = [int(i.split('-')[0]) for i in TestMovieTable.Release]

# %%
test = TestMovieTable[TestMovieTable.Director_AR>0]
test = test[test.Actor_CR>0]

# %%
from sklearn import linear_model as lm

# %% [markdown]
# #### Predict the result.

# %%
reg = lm.LinearRegression()
reg.fit(MovieTable[['Audience_rating', 'Critic_rating', 'Director_BoxOffice', 'Director_BoxOffice_Sum', 'Director_Count', 'Director_CR', 'Genre_BoxOffice', 'Actor_BoxOffice_Sum', 'ReleaseYear']], MovieTable['log'])
prediction = reg.predict(test[['Audience_rating', 'Critic_rating', 'Director_BoxOffice', 'Director_BoxOffice_Sum', 'Director_Count', 'Director_CR', 'Genre_BoxOffice', 'Actor_BoxOffice_Sum', 'ReleaseYear']])
test['PredictBoxOffice'] = np.exp(prediction)

# %%
PredictRank = test.sort(columns='PredictBoxOffice', ascending=False)
PredictRank.reset_index(inplace=True, drop = True)
RealRank = test.sort(columns='BoxOffice', ascending=False)
RealRank.reset_index(inplace=True, drop = True)

# %%
result = pd.DataFrame([PredictRank.Movie,PredictRank.PredictBoxOffice,PredictRank.Audience_rating, 
                       PredictRank.Critic_rating, RealRank.Movie, RealRank.BoxOffice, 
                       RealRank.Audience_rating, RealRank.Critic_rating]).transpose()
result
# Out:
#                                 Movie PredictBoxOffice Audience_rating  \
# 0                               Rio 2     2.689465e+08              60
# 1     Transformers: Age of Extinction     2.244726e+08              53
# 2          X-Men: Days of Future Past     1.822755e+08              92
# 3                            Hercules     1.664921e+08              53
# 4   Live Die Repeat: Edge of Tomorrow     1.067501e+08              91
# 5            The Amazing Spider-Man 2     8.054901e+07              67
# 6                             Blended     5.209018e+07              65
# 7                          Ride Along      3.93458e+07              60
# 8                           Divergent     2.622873e+07              71
# 9                                Noah     2.542664e+07              43
# 10                          Draft Day     2.378936e+07              66
# 11                      Walk Of Shame     1.960446e+07              39
# 12                            Pompeii     1.915614e+07              36
# 13                               Lucy     1.889202e+07              47
# 14               Think Like a Man Too     1.877934e+07              61
# 15                           Non-Stop     1.791869e+07              65
# 16          Jack Ryan: Shadow Recruit      1.53757e+07              54
# 17               The Single Moms Club      1.48849e+07              60
# 18             Magic in the Moonlight     1.384466e+07              53
# 19                            Boyhood     1.120198e+07              89
# 20                  The Monuments Men     1.021351e+07              44
# 21                   About Last Night          9528632              67
# 22                 Heaven Is for Real          9186020              67
# 23     Dawn Of The Planet Of The Apes          9140064              90
# 24                           Sex Tape          7098980              34
#
#    Critic_rating                              Movie  BoxOffice  \
# 0             48    Transformers: Age of Extinction  245435927
# 1             18         X-Men: Days of Future Past  233893992
# 2             92     Dawn Of The Planet Of The Apes  207604640
# 3             58           The Amazing Spider-Man 2  202644001
# 4             90                          Divergent  150947895
# 5             53                         Ride Along  134141530
# 6             14                              Rio 2  131020633
# 7             17                               Lucy  125480625
# 8             41                               Noah  101160529
# 9             77  Live Die Repeat: Edge of Tomorrow   99992247
# 10            60                 Heaven Is for Real   91386097
# 11            12                           Non-Stop   91104080
# 12            29                  The Monuments Men   77951843
# 13            66                           Hercules   72385417
# 14            23               Think Like a Man Too   65028687
# 15            60          Jack Ryan: Shadow Recruit   50549107
# 16            56                   About Last Night   48637684
# 17            16                            Blended   45889191
# 18            51                           Sex Tape   33880665
# 19            99                          Draft Day   28831145
# 20            31                            Pompeii   23219748
# 21            68                            Boyhood   23016519
# 22            46               The Single Moms Club   15986272
# 23            91             Magic in the Moonlight   10323802
# 24            18                      Walk Of Shame      39751
#
#    Audience_rating Critic_rating
# 0               53            18
# 1               92            92
# 2               90            91
# 3               67            53
# 4               71            41
# 5               60            17
# 6               60            48
# 7               47            66
# 8               43            77
# 9               91            90
# 10              67            46
# 11              65            60
# 12              44            31
# 13              53            58
# 14              61            23
# 15              54            56
# 16              67            68
# 17              65            14
# 18              34            18
# 19              66            60
# 20              36            29
# 21              89            99
# 22              60            16
# 23              53            51
# 24              39            12

# %% [markdown]
# ####The result above shows the predicted rank of movies and the real rank of movies in the first half of 2014. Only movies with complete data are included. In the top 10 movies, we missed 3 movies.

# %%
RealRank['RealRank'] = range(1, len(result)+1)
PredictRank['PredictRank'] = range(1, len(result)+1)

# %%
resultplot = pd.merge(RealRank[['Movie', 'RealRank']], PredictRank[['Movie', 'PredictRank']], on='Movie')

# %%
from pandas.tools.plotting import parallel_coordinates
resultplot = resultplot[['Movie', 'RealRank', 'PredictRank']]
plt.figure(figsize=(8,6))
ax = parallel_coordinates(resultplot, 'Movie')
plt.ylabel('Rank')
plt.title('Real and Predicted Rank for 2014 Movies')
legend = ax.legend()
legend.set_visible(False)

# %%
plt.figure(figsize=(8, 6), dpi=300)
ax = parallel_coordinates(test[['Movie', 'BoxOffice', 'PredictBoxOffice']], 'Movie')
legend = ax.legend()
plt.ylabel('Boxoffice')
plt.title('Real and Predicted Box Office for 2014 Movies')
legend.set_visible(False)
