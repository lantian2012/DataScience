# %%
import oauth2 as oauth
import time
import json
#home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', 'abcdefg', 'hijklmnop' )

# %%
CONSUMER_KEY = "ZanES4cy8hufvy2yjTLFG8tbO"
CONSUMER_SECRET = "uSbXql55opsnhzGyUlRngp72ZrjjTDNrtkXRHJZ2nTmJJCQ5Mi"
key = "2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU"
secret = "I7doox0PWs22EUMIqFPnk7SqMDFydethoOOR83Wif954f"

# %%
def oauth_req(url, key, secret, http_method="GET", post_body=None, http_headers=None):
    consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
    token = oauth.Token(key=key, secret=secret)
    client = oauth.Client(consumer, token)
    resp, content = client.request( url, method=http_method, body=post_body, headers=http_headers)
    return content

# %%
url1 = "https://api.twitter.com/1.1/statuses/home_timeline.json"
url2 = "https://api.twitter.com/1.1/users/search.json?amp%3Bcount=3&amp%3Bpage=1&q=Twitter+API"
url3 = "https://stream.twitter.com/1.1/statuses/sample.json"
home_timeline = oauth_req( url2, key, secret )
json.loads(home_timeline)
# Out:
# <oauth2.Client object at 0x104532550>
# {u'errors': [{u'code': 32, u'message': u'Could not authenticate you'}]}

# %%
#home_timeline = oauth_req( 'https://api.twitter.com/1.1/users/search.json?q=&page=1&count=3', key, secret )

# %%
type(home_timeline)
# Out:
# str

# %%
# -*- coding: utf-8 -*-
"""
Yelp API v2.0 code sample.

This program demonstrates the capability of the Yelp API version 2.0
by using the Search API to query for businesses by a search term and location,
and the Business API to query additional information about the top result
from the search query.

Please refer to http://www.yelp.com/developers/documentation for the API documentation.

This program requires the Python oauth2 library, which you can install via:
`pip install -r requirements.txt`.

Sample usage of the program:
`python sample.py --term="bars" --location="San Francisco, CA"`
"""
import argparse
import json
import pprint
import sys
import urllib
import urllib2

import oauth2


API_HOST = 'api.twitter.com'
SEARCH_PATH = '/1.1/users/search/'

# OAuth credential placeholders that must be filled in by users.
import oauth2 as oauth
import time

def request(host, path, url_params=None):
    """Prepares OAuth authentication and sends the request to the API.

    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        url_params (dict): An optional set of query parameters in the request.

    Returns:
        dict: The JSON response from the request.

    Raises:
        urllib2.HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = 'https://{0}{1}?'.format(host, path)

    consumer = oauth2.Consumer(CONSUMER_KEY, CONSUMER_SECRET)
    oauth_request = oauth2.Request(method="GET", url=url, parameters=url_params)

    oauth_request.update(
        {
            'oauth_nonce': oauth2.generate_nonce(),
            'oauth_timestamp': oauth2.generate_timestamp(),
            'oauth_token': TOKEN,
            'oauth_consumer_key': CONSUMER_KEY
        }
    )
    token = oauth2.Token(TOKEN, TOKEN_SECRET)
    oauth_request.sign_request(oauth2.SignatureMethod_HMAC_SHA1(), consumer, token)
    signed_url = oauth_request.to_url()
    signed_url = 'https://api.twitter.com/1.1/users/search.json?count=3&page=1&oauth_consumer_key=ZanES4cy8hufvy2yjTLFG8tbO&oauth_nonce=0368e8ceddec51fe89a696ab67cf42e9&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1416888677&oauth_token=2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU&oauth_version=1.0&q=Twitter'
    print signed_url
    
    print 'Querying {0} ...'.format(url)

    conn = urllib2.urlopen(signed_url, None)
    try:
        response = json.loads(conn.read())
    finally:
        conn.close()

    return response

def searchUser(term):
    """Query the Search API by a search term and location.

    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.

    Returns:
        dict: The JSON response from the request.
    """
    # https://api.twitter.com/1.1/users/search.json?q=&page=1&count=3
    url_params = {
        'q': term.replace(' ', '+'),
        'page': 1,
        'count': 1
        
        #'limit': SEARCH_LIMIT,
        #'sort':1,
        #'category_filter':'dimsum'
    }
    return request(API_HOST, SEARCH_PATH, url_params=url_params)


def search(term, location):
    """Query the Search API by a search term and location.

    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.

    Returns:
        dict: The JSON response from the request.
    """
    
    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'sort':1,
        'category_filter':'dimsum'
    }
    return request(API_HOST, SEARCH_PATH, url_params=url_params)

def get_business(business_id):
    """Query the Business API by a business ID.

    Args:
        business_id (str): The ID of the business to query.

    Returns:
        dict: The JSON response from the request.
    """
    business_path = BUSINESS_PATH + business_id

    return request(API_HOST, business_path)

# %%
searchUser("kobe")
# Out:
# https://api.twitter.com/1.1/users/search.json?count=3&page=1&oauth_consumer_key=ZanES4cy8hufvy2yjTLFG8tbO&oauth_nonce=0368e8ceddec51fe89a696ab67cf42e9&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1416888677&oauth_token=2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU&oauth_version=1.0&q=Twitter
# Querying https://api.twitter.com/1.1/users/search/? ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-107-b5e046332840> in <module>()
# ----> 1 searchUser("kobe")
#
# <ipython-input-106-ff9ee7a9fbb5> in searchUser(term)
#      97         #'category_filter':'dimsum'
#      98     }
# ---> 99     return request(API_HOST, SEARCH_PATH, url_params=url_params)
#     100
#     101
#
# <ipython-input-106-ff9ee7a9fbb5> in request(host, path, url_params)
#      69     print 'Querying {0} ...'.format(url)
#      70
# ---> 71     conn = urllib2.urlopen(signed_url, None)
#      72     try:
#      73         response = json.loads(conn.read())
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout)
#     125     if _opener is None:
#     126         _opener = build_opener()
# --> 127     return _opener.open(url, data, timeout)
#     128
#     129 def install_opener(opener):
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     408         for processor in self.process_response.get(protocol, []):
#     409             meth = getattr(processor, meth_name)
# --> 410             response = meth(req, response)
#     411
#     412         return response
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     521         if not (200 <= code < 300):
#     522             response = self.parent.error(
# --> 523                 'http', request, response, code, msg, hdrs)
#     524
#     525         return response
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     446         if http_err:
#     447             args = (dict, 'default', 'http_error_default') + orig_args
# --> 448             return self._call_chain(*args)
#     449
#     450 # XXX probably also want an abstract factory that knows when it makes
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     380             func = getattr(handler, meth_name)
#     381
# --> 382             result = func(*args)
#     383             if result is not None:
#     384                 return result
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in http_error_default(self, req, fp, code, msg, hdrs)
#     529 class HTTPDefaultErrorHandler(BaseHandler):
#     530     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 531         raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
#     532
#     533 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
CONSUMER_KEY = "ZanES4cy8hufvy2yjTLFG8tbO"
CONSUMER_SECRET = "uSbXql55opsnhzGyUlRngp72ZrjjTDNrtkXRHJZ2nTmJJCQ5Mi"
key = "2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU"
secret = "I7doox0PWs22EUMIqFPnk7SqMDFydethoOOR83Wif954f"


import oauth2 as oauth
import time

# Set the API endpoint 
url = "http://example.com/photos"

# Set the base oauth_* parameters along with any other parameters required
# for the API call.
params = {
    'oauth_version': "1.0",
    'oauth_nonce': oauth.generate_nonce(),
    'oauth_timestamp': int(time.time())
    #'user': 'joestump',
    #'photoid': 555555555555
}

# Set up instances of our Token and Consumer. The Consumer.key and 
# Consumer.secret are given to you by the API provider. The Token.key and
# Token.secret is given to you after a three-legged authentication.
token = oauth.Token(key=key, secret=secret)
consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)

# Set our token/key parameters
params['oauth_token'] = token.key
params['oauth_consumer_key'] = consumer.key

# Create our request. Change method, etc. accordingly.
req = oauth.Request(method="GET", url=url, parameters=params)

# Sign the request.
signature_method = oauth.SignatureMethod_HMAC_SHA1()
req.sign_request(signature_method, consumer, token)

# %%
# Out:
# oauth2.Request

# %%
# Create your consumer with the proper key/secret.
#consumer = oauth.Consumer(key="your-twitter-consumer-key", 
#    secret="your-twitter-consumer-secret")

# Request token URL for Twitter.
request_token_url = "http://twitter.com/oauth/request_token"

# Create our client.
client = oauth.Client(consumer)

# The OAuth Client request works just like httplib2 for the most part.
resp, content = client.request(request_token_url, "GET")
#print resp
print content
# Out:
# Failed to validate oauth signature and token

# %%
def oauth_req(url, key, secret, http_method="GET", post_body=None, http_headers=None):
    consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
    token = oauth.Token(key=key, secret=secret)
    client = oauth.Client(consumer, token)
    resp, content = client.request( url, method=http_method, body=post_body, headers=http_headers, force_auth_header=True )
    return content 
home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', key, secret )
# Out:
#   File "<ipython-input-66-4abf38a4604d>", line 2
#     consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
#     ^
# SyntaxError: invalid syntax

# %%
import oauth2 as oauth
import urllib2 as urllib


# See assignment1.html instructions or README for how to get these credentials

api_key = "ZanES4cy8hufvy2yjTLFG8tbO"
api_secret = "uSbXql55opsnhzGyUlRngp72ZrjjTDNrtkXRHJZ2nTmJJCQ5Mi"
access_token_key = "2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU"
access_token_secret = "I7doox0PWs22EUMIqFPnk7SqMDFydethoOOR83Wif954f"

_debug = 0

oauth_token    = oauth.Token(key=access_token_key, secret=access_token_secret)
oauth_consumer = oauth.Consumer(key=api_key, secret=api_secret)

signature_method_hmac_sha1 = oauth.SignatureMethod_HMAC_SHA1()

http_method = "GET"


http_handler  = urllib.HTTPHandler(debuglevel=_debug)
https_handler = urllib.HTTPSHandler(debuglevel=_debug)

'''
Construct, sign, and open a twitter request
using the hard-coded credentials above.
'''
def twitterreq(url, method, parameters):
  req = oauth.Request.from_consumer_and_token(oauth_consumer,
                                             token=oauth_token,
                                             http_method=http_method,
                                             http_url=url, 
                                             parameters=parameters)

  req.sign_request(signature_method_hmac_sha1, oauth_consumer, oauth_token)

  headers = req.to_header()

  if http_method == "POST":
    encoded_post_data = req.to_postdata()
  else:
    encoded_post_data = None
    url = req.to_url()

  opener = urllib.OpenerDirector()
  opener.add_handler(http_handler)
  opener.add_handler(https_handler)

  response = opener.open(url, encoded_post_data)

  return response

def fetchsamples():
  url = "https://api.twitter.com/1.1/users/search.json?q=Twitter%20API&page=1&count=3"
  parameters = []
  response = twitterreq(url, "GET", parameters)
  #for line in response[0:20]:
  #  print line.strip()
  return response

# %%
out = fetchsamples()

# %%
type(out)
# Out:
# instance

# %%
out.readline()
# Out:
# '{"errors":[{"code":25,"message":"Query parameters are missing."}]}'

# %%
import json
from application_only_auth import Client


CONSUMER_KEY = 'L96guHuxCIRxz0quUVCNkHYL7'
CONSUMER_SECRET = 'kSHrrjByp6OyjQM0pFcYTlGE3olASilkIhkBbAuGebZPXGnBVB'

client = Client(CONSUMER_KEY, CONSUMER_SECRET)

# Pretty print of tweet payload
tweet = client.request('https://api.twitter.com/1.1/search/tweets.json?q=emma+watson')
#tweet = client.request('https://api.twitter.com/1.1/users/lookup.json?screen_name=twitterapi')
#tweet = client.request('https://api.twitter.com/1.1/users/search.json?q=Twitter')
print json.dumps(tweet, sort_keys=True, indent=1, separators=(',', ':'))
# Out:
# {
#  "search_metadata":{
#   "completed_in":0.021,
#   "count":15,
#   "max_id":539170342103941121,
#   "max_id_str":"539170342103941121",
#   "next_results":"?max_id=539170333878923263&q=emma%20watson&include_entities=1",
#   "query":"emma+watson",
#   "refresh_url":"?since_id=539170342103941121&q=emma%20watson&include_entities=1",
#   "since_id":0,
#   "since_id_str":"0"
#  },
#  "statuses":[
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:21 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170342103941121,
#    "id_str":"539170342103941121",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Fri Jul 05 18:26:15 +0000 2013",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"Hola!! Aca MANDA y DOMINA TODO mi ser zaira :3 ella es la unica que me puede la minions de juan :') safen gatas ah  loviu... @Zaira_yannett *L\u00f3S d\u00c9l F\u00f3Nd\u00d3*",
#     "entities":{
#      "description":{
#       "urls":[]
#      },
#      "url":{
#       "urls":[
#        {
#         "display_url":"facebook.com/juanmartin.roj\u2026",
#         "expanded_url":"https://www.facebook.com/juanmartin.rojas.39",
#         "indices":[
#          0,
#          23
#         ],
#         "url":"https://t.co/0yy4lIEzaF"
#        }
#       ]
#      }
#     },
#     "favourites_count":91,
#     "follow_request_sent":null,
#     "followers_count":160,
#     "following":null,
#     "friends_count":121,
#     "geo_enabled":false,
#     "id":1571095676,
#     "id_str":"1571095676",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":"",
#     "name":"amo a mi potato :3",
#     "notifications":null,
#     "profile_background_color":"AD2121",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/479839729391661056/O1E0ifEz.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/479839729391661056/O1E0ifEz.jpeg",
#     "profile_background_tile":false,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/1571095676/1412952386",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/519582661740748800/PJEHOtCK_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/519582661740748800/PJEHOtCK_normal.jpeg",
#     "profile_link_color":"A61212",
#     "profile_location":null,
#     "profile_sidebar_border_color":"000000",
#     "profile_sidebar_fill_color":"DDEEF6",
#     "profile_text_color":"333333",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"Rojaas_Juan",
#     "statuses_count":5269,
#     "time_zone":"Buenos Aires",
#     "url":"https://t.co/0yy4lIEzaF",
#     "utc_offset":-10800,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:21 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170341609029632,
#    "id_str":"539170341609029632",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Sun Jan 19 22:18:13 +0000 2014",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"- Nadaa Mee Importtaa;' Mee Importtaaa Unaa Miierdaa;' Loo Quee Piiensees Dee Mii'; Sii Noo Tee CaiiQquoo Biien'; Cojee Un Turnoo & Esperaaa \u263b_\u263b''''",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":158,
#     "follow_request_sent":null,
#     "followers_count":80,
#     "following":null,
#     "friends_count":43,
#     "geo_enabled":false,
#     "id":2300404776,
#     "id_str":"2300404776",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":"",
#     "name":"- \u015ao\u013eOh \u0106o\u03aett\u00ed\u00edG\u03cdOh\u2605",
#     "notifications":null,
#     "profile_background_color":"4A913C",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/529918594931367936/6-n-8cQW.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/529918594931367936/6-n-8cQW.jpeg",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/2300404776/1415177300",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/538229135164715011/IbDZi5D3_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/538229135164715011/IbDZi5D3_normal.jpeg",
#     "profile_link_color":"DD2E44",
#     "profile_location":null,
#     "profile_sidebar_border_color":"FFFFFF",
#     "profile_sidebar_fill_color":"DDEEF6",
#     "profile_text_color":"333333",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"Yayiih_X3",
#     "statuses_count":6267,
#     "time_zone":"Atlantic Time (Canada)",
#     "url":null,
#     "utc_offset":-14400,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:21 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170340887601152,
#    "id_str":"539170340887601152",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Mon Jan 03 14:59:00 +0000 2011",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"hagamos algo superficial y vulgar",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":115,
#     "follow_request_sent":null,
#     "followers_count":217,
#     "following":null,
#     "friends_count":632,
#     "geo_enabled":true,
#     "id":233556291,
#     "id_str":"233556291",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":"YOUR",
#     "name":"Gara Jova",
#     "notifications":null,
#     "profile_background_color":"EB12EB",
#     "profile_background_image_url":"http://abs.twimg.com/images/themes/theme14/bg.gif",
#     "profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme14/bg.gif",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/233556291/1416772268",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/535849797203558400/VxnV-7Ot_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/535849797203558400/VxnV-7Ot_normal.jpeg",
#     "profile_link_color":"F711D5",
#     "profile_location":null,
#     "profile_sidebar_border_color":"FFFFFF",
#     "profile_sidebar_fill_color":"EFEFEF",
#     "profile_text_color":"333333",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"xandra_RCCV",
#     "statuses_count":5829,
#     "time_zone":"Athens",
#     "url":null,
#     "utc_offset":7200,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:21 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[],
#     "user_mentions":[
#      {
#       "id":1886548909,
#       "id_str":"1886548909",
#       "indices":[
#        3,
#        15
#       ],
#       "name":"cl\u00e0 \u2728",
#       "screen_name":"besideharry"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170340501741568,
#    "id_str":"539170340501741568",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"it",
#    "metadata":{
#     "iso_language_code":"it",
#     "result_type":"recent"
#    },
#    "place":null,
#    "retweet_count":161,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 15:20:14 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[],
#      "user_mentions":[]
#     },
#     "favorite_count":176,
#     "favorited":false,
#     "geo":null,
#     "id":539076442286731264,
#     "id_str":"539076442286731264",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"it",
#     "metadata":{
#      "iso_language_code":"it",
#      "result_type":"recent"
#     },
#     "place":null,
#     "retweet_count":161,
#     "retweeted":false,
#     "source":"<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text":"'infanzia traumatizzata'\nemma watson partecip\u00f2 all'audizione per harry potter per gioco.",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Fri Sep 20 13:16:53 +0000 2013",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"I fell in love with harry. not for how he looks, just for who he is.",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":12411,
#      "follow_request_sent":null,
#      "followers_count":9628,
#      "following":null,
#      "friends_count":4095,
#      "geo_enabled":true,
#      "id":1886548909,
#      "id_str":"1886548909",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"it",
#      "listed_count":353,
#      "location":"mai na gioia",
#      "name":"cl\u00e0 \u2728",
#      "notifications":null,
#      "profile_background_color":"FFFFFF",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/378800000122429911/318db13343eb3588f61c469923fc22ac.png",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/378800000122429911/318db13343eb3588f61c469923fc22ac.png",
#      "profile_background_tile":false,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/1886548909/1417293362",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/536636206067757056/Bj-sp4Y2_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/536636206067757056/Bj-sp4Y2_normal.jpeg",
#      "profile_link_color":"000000",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":false,
#      "protected":false,
#      "screen_name":"besideharry",
#      "statuses_count":44444,
#      "time_zone":"Athens",
#      "url":null,
#      "utc_offset":7200,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "text":"RT @besideharry: 'infanzia traumatizzata'\nemma watson partecip\u00f2 all'audizione per harry potter per gioco.",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Thu Apr 19 13:23:43 +0000 2012",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"@Louis_Tomlinson se avessi la certezza di abbracciarti,vivrei la vita aspettando. {@Luke5SOS 11.03.14} @haroldstringimi \u00e8 la mia queen\u265b 29.06.14 - 07.12.14",
#     "entities":{
#      "description":{
#       "urls":[]
#      },
#      "url":{
#       "urls":[
#        {
#         "display_url":"m.facebook.com/eleonora.morin\u2026",
#         "expanded_url":"https://m.facebook.com/eleonora.morina?ref=bookmark",
#         "indices":[
#          0,
#          23
#         ],
#         "url":"https://t.co/temG7m5lGo"
#        }
#       ]
#      }
#     },
#     "favourites_count":5354,
#     "follow_request_sent":null,
#     "followers_count":5874,
#     "following":null,
#     "friends_count":3936,
#     "geo_enabled":true,
#     "id":557792760,
#     "id_str":"557792760",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"it",
#     "listed_count":11,
#     "location":"Lou's arms.",
#     "name":"El. | 07.12.14",
#     "notifications":null,
#     "profile_background_color":"FFFFFF",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/464447331803230209/GMxyb2fo.png",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/464447331803230209/GMxyb2fo.png",
#     "profile_background_tile":false,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/557792760/1417257146",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/538641637514424320/xZkkBAXU_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/538641637514424320/xZkkBAXU_normal.jpeg",
#     "profile_link_color":"000000",
#     "profile_location":null,
#     "profile_sidebar_border_color":"000000",
#     "profile_sidebar_fill_color":"95E8EC",
#     "profile_text_color":"3C3940",
#     "profile_use_background_image":false,
#     "protected":false,
#     "screen_name":"loustringimi",
#     "statuses_count":16614,
#     "time_zone":"Ljubljana",
#     "url":"https://t.co/temG7m5lGo",
#     "utc_offset":3600,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:21 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170340191367168,
#    "id_str":"539170340191367168",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Fri Apr 29 14:22:35 +0000 2011",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"Gathithen\u2665 // GNR\u221e\u2665 :D // ''Nada dura para siempre y los dos sabemos que los corazones pueden cambiar''.// #Mafia #Humildad #Respeto #RPM //",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":169,
#     "follow_request_sent":null,
#     "followers_count":496,
#     "following":null,
#     "friends_count":396,
#     "geo_enabled":false,
#     "id":289959789,
#     "id_str":"289959789",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":4,
#     "location":"",
#     "name":"ReBoludeada#1 ",
#     "notifications":null,
#     "profile_background_color":"1CBEC4",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/533070139353083905/70ENl7SX.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/533070139353083905/70ENl7SX.jpeg",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/289959789/1417136701",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/533070853374619648/9hJbWE0S_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/533070853374619648/9hJbWE0S_normal.jpeg",
#     "profile_link_color":"FA1564",
#     "profile_location":null,
#     "profile_sidebar_border_color":"FFFFFF",
#     "profile_sidebar_fill_color":"78C0A8",
#     "profile_text_color":"5E412F",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"Aguus_Alcibar",
#     "statuses_count":8897,
#     "time_zone":"Buenos Aires",
#     "url":null,
#     "utc_offset":-10800,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:20 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170339033731073,
#    "id_str":"539170339033731073",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Sun Jul 14 19:41:35 +0000 2013",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":116,
#     "follow_request_sent":null,
#     "followers_count":318,
#     "following":null,
#     "friends_count":627,
#     "geo_enabled":false,
#     "id":1594122398,
#     "id_str":"1594122398",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":"",
#     "name":"~Principe The Gold~",
#     "notifications":null,
#     "profile_background_color":"C0DEED",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/378800000123127586/a59407f3dd84efa04a59ea1f7c77eb73.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/378800000123127586/a59407f3dd84efa04a59ea1f7c77eb73.jpeg",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/1594122398/1416922682",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/537238791959085056/6LH23w07_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/537238791959085056/6LH23w07_normal.jpeg",
#     "profile_link_color":"0084B4",
#     "profile_location":null,
#     "profile_sidebar_border_color":"FFFFFF",
#     "profile_sidebar_fill_color":"DDEEF6",
#     "profile_text_color":"333333",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"rafika_10",
#     "statuses_count":306,
#     "time_zone":null,
#     "url":null,
#     "utc_offset":null,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:20 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170338681397249,
#    "id_str":"539170338681397249",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Thu Oct 06 00:17:56 +0000 2011",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"Conoceme Futuro no se! Madridista, Orgulloso, Realista! Opositor100% Maracucho !",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":732,
#     "follow_request_sent":null,
#     "followers_count":260,
#     "following":null,
#     "friends_count":259,
#     "geo_enabled":false,
#     "id":385713386,
#     "id_str":"385713386",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":"Zulia, Maracaibo",
#     "name":"Gustavo Parra!! ",
#     "notifications":null,
#     "profile_background_color":"131516",
#     "profile_background_image_url":"http://abs.twimg.com/images/themes/theme14/bg.gif",
#     "profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme14/bg.gif",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/385713386/1409109178",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/504468607309332481/iSLFkw0E_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/504468607309332481/iSLFkw0E_normal.jpeg",
#     "profile_link_color":"009999",
#     "profile_location":null,
#     "profile_sidebar_border_color":"EEEEEE",
#     "profile_sidebar_fill_color":"EFEFEF",
#     "profile_text_color":"333333",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"Gparra2",
#     "statuses_count":27040,
#     "time_zone":"Hawaii",
#     "url":null,
#     "utc_offset":-36000,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:20 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170338199060480,
#    "id_str":"539170338199060480",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Wed Jun 25 20:53:02 +0000 2014",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"LO QUE AMO DE MI: ES MI BOLUDES ,LAS PELOTUDECES QUE DIGO ETC",
# ...
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Thu Apr 28 00:03:33 +0000 2011",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"15. FCB~CARP~ CAJB.",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":544,
#     "follow_request_sent":null,
#     "followers_count":326,
#     "following":null,
#     "friends_count":309,
#     "geo_enabled":true,
#     "id":289075584,
#     "id_str":"289075584",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":" Barranquilla/Colombia",
#     "name":"JS.",
#     "notifications":null,
#     "profile_background_color":"1A1B1F",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/435100307303825408/VlGY_GJN.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/435100307303825408/VlGY_GJN.jpeg",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/289075584/1395693950",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/536566801963155457/ElCtsq7N_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/536566801963155457/ElCtsq7N_normal.jpeg",
#     "profile_link_color":"2FC2EF",
#     "profile_location":null,
#     "profile_sidebar_border_color":"FFFFFF",
#     "profile_sidebar_fill_color":"252429",
#     "profile_text_color":"666666",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"iJuansehdez",
#     "statuses_count":21027,
#     "time_zone":"Eastern Time (US & Canada)",
#     "url":null,
#     "utc_offset":-18000,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:19 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170334709395457,
#    "id_str":"539170334709395457",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Fri Aug 17 12:44:39 +0000 2012",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"Futbol: mas que un deporte mi vida\u2665",
#     "entities":{
#      "description":{
#       "urls":[]
#      },
#      "url":{
#       "urls":[
#        {
#         "display_url":"facebook.com/joaco.martiine\u2026",
#         "expanded_url":"http://www.facebook.com/joaco.martiinez?ref=tn_tnmn",
#         "indices":[
#          0,
#          22
#         ],
#         "url":"http://t.co/DYrQ11klG3"
#        }
#       ]
#      }
#     },
#     "favourites_count":3163,
#     "follow_request_sent":null,
#     "followers_count":796,
#     "following":null,
#     "friends_count":313,
#     "geo_enabled":true,
#     "id":763646348,
#     "id_str":"763646348",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":2,
#     "location":"Uruguay",
#     "name":"Cassio y Joaq",
#     "notifications":null,
#     "profile_background_color":"89C9FA",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/506600410950270977/5VXfyFN0.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/506600410950270977/5VXfyFN0.jpeg",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/763646348/1411245441",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/505908938684891136/WfwdNgkb_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/505908938684891136/WfwdNgkb_normal.jpeg",
#     "profile_link_color":"3B94D9",
#     "profile_location":null,
#     "profile_sidebar_border_color":"000000",
#     "profile_sidebar_fill_color":"DDEEF6",
#     "profile_text_color":"333333",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"MartinezzJoaq",
#     "statuses_count":28689,
#     "time_zone":"Mid-Atlantic",
#     "url":"http://t.co/DYrQ11klG3",
#     "utc_offset":-7200,
#     "verified":false
#    }
#   },
#   {
#    "contributors":null,
#    "coordinates":null,
#    "created_at":"Sun Nov 30 21:33:19 +0000 2014",
#    "entities":{
#     "hashtags":[],
#     "symbols":[],
#     "urls":[
#      {
#       "display_url":"bit.ly/1wyDct3",
#       "expanded_url":"http://bit.ly/1wyDct3",
#       "indices":[
#        87,
#        109
#       ],
#       "url":"http://t.co/DJRx6iDd2N"
#      }
#     ],
#     "user_mentions":[
#      {
#       "id":904617768,
#       "id_str":"904617768",
#       "indices":[
#        3,
#        19
#       ],
#       "name":"Eduardo segovia",
#       "screen_name":"Eduardosegovia9"
#      }
#     ]
#    },
#    "favorite_count":0,
#    "favorited":false,
#    "geo":null,
#    "id":539170333878923264,
#    "id_str":"539170333878923264",
#    "in_reply_to_screen_name":null,
#    "in_reply_to_status_id":null,
#    "in_reply_to_status_id_str":null,
#    "in_reply_to_user_id":null,
#    "in_reply_to_user_id_str":null,
#    "lang":"es",
#    "metadata":{
#     "iso_language_code":"es",
#     "result_type":"recent"
#    },
#    "place":null,
#    "possibly_sensitive":false,
#    "retweet_count":5710,
#    "retweeted":false,
#    "retweeted_status":{
#     "contributors":null,
#     "coordinates":null,
#     "created_at":"Sun Nov 30 20:59:04 +0000 2014",
#     "entities":{
#      "hashtags":[],
#      "symbols":[],
#      "urls":[
#       {
#        "display_url":"bit.ly/1wyDct3",
#        "expanded_url":"http://bit.ly/1wyDct3",
#        "indices":[
#         66,
#         88
#        ],
#        "url":"http://t.co/DJRx6iDd2N"
#       }
#      ],
#      "user_mentions":[]
#     },
#     "favorite_count":8,
#     "favorited":false,
#     "geo":null,
#     "id":539161714416443393,
#     "id_str":"539161714416443393",
#     "in_reply_to_screen_name":null,
#     "in_reply_to_status_id":null,
#     "in_reply_to_status_id_str":null,
#     "in_reply_to_user_id":null,
#     "in_reply_to_user_id_str":null,
#     "lang":"es",
#     "metadata":{
#      "iso_language_code":"es",
#      "result_type":"recent"
#     },
#     "place":null,
#     "possibly_sensitive":false,
#     "retweet_count":5710,
#     "retweeted":false,
#     "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text":"PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#     "truncated":false,
#     "user":{
#      "contributors_enabled":false,
#      "created_at":"Thu Oct 25 20:34:16 +0000 2012",
#      "default_profile":false,
#      "default_profile_image":false,
#      "description":"En tu vida puedes hacer de todo un problema, o de todo una soluci\u00f3n, seg\u00fan que hagas tendr\u00e1s tu vida llena de problemas, o de soluciones.La mia es una solucion!",
#      "entities":{
#       "description":{
#        "urls":[]
#       }
#      },
#      "favourites_count":3,
#      "follow_request_sent":null,
#      "followers_count":394,
#      "following":null,
#      "friends_count":77,
#      "geo_enabled":false,
#      "id":904617768,
#      "id_str":"904617768",
#      "is_translation_enabled":false,
#      "is_translator":false,
#      "lang":"es",
#      "listed_count":0,
#      "location":"Sevilla",
#      "name":"Eduardo segovia",
#      "notifications":null,
#      "profile_background_color":"131516",
#      "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/445982391681572864/uT4E7IMO.jpeg",
#      "profile_background_tile":true,
#      "profile_banner_url":"https://pbs.twimg.com/profile_banners/904617768/1395094190",
#      "profile_image_url":"http://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_image_url_https":"https://pbs.twimg.com/profile_images/477134663774134273/AiI605O9_normal.jpeg",
#      "profile_link_color":"009999",
#      "profile_location":null,
#      "profile_sidebar_border_color":"FFFFFF",
#      "profile_sidebar_fill_color":"DDEEF6",
#      "profile_text_color":"333333",
#      "profile_use_background_image":true,
#      "protected":false,
#      "screen_name":"Eduardosegovia9",
#      "statuses_count":60,
#      "time_zone":null,
#      "url":null,
#      "utc_offset":null,
#      "verified":false
#     }
#    },
#    "source":"<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "text":"RT @Eduardosegovia9: PRIMICIA: Foto exclusiva de Emma Watson sin la parte de arriba!!\n\nhttp://t.co/DJRx6iDd2N",
#    "truncated":false,
#    "user":{
#     "contributors_enabled":false,
#     "created_at":"Thu Dec 27 11:24:31 +0000 2012",
#     "default_profile":false,
#     "default_profile_image":false,
#     "description":"Dios no es religion, Dios es VIDA!! TODO es posible si puedes creer..  Dios no rechaza oracion  # 130 dias #",
#     "entities":{
#      "description":{
#       "urls":[]
#      }
#     },
#     "favourites_count":16951,
#     "follow_request_sent":null,
#     "followers_count":679,
#     "following":null,
#     "friends_count":481,
#     "geo_enabled":false,
#     "id":1039420387,
#     "id_str":"1039420387",
#     "is_translation_enabled":false,
#     "is_translator":false,
#     "lang":"es",
#     "listed_count":0,
#     "location":"A todos lados con SRB",
#     "name":"GraciasChespirito\u2665",
#     "notifications":null,
#     "profile_background_color":"DD2E44",
#     "profile_background_image_url":"http://pbs.twimg.com/profile_background_images/536585789371453440/U7zxFhx7.jpeg",
#     "profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/536585789371453440/U7zxFhx7.jpeg",
#     "profile_background_tile":true,
#     "profile_banner_url":"https://pbs.twimg.com/profile_banners/1039420387/1417228737",
#     "profile_image_url":"http://pbs.twimg.com/profile_images/538773284117299201/oLkILQ1l_normal.jpeg",
#     "profile_image_url_https":"https://pbs.twimg.com/profile_images/538773284117299201/oLkILQ1l_normal.jpeg",
#     "profile_link_color":"9266CC",
#     "profile_location":null,
#     "profile_sidebar_border_color":"000000",
#     "profile_sidebar_fill_color":"95E8EC",
#     "profile_text_color":"3C3940",
#     "profile_use_background_image":true,
#     "protected":false,
#     "screen_name":"nickidoradoo",
#     "statuses_count":50432,
#     "time_zone":"Brasilia",
#     "url":null,
#     "utc_offset":-7200,
#     "verified":false
#    }
#   }
#  ]
# }

# %%
import oauth2 as oauth
def oauth_req(url, key, secret, http_method="GET", post_body=None, http_headers=None):
    consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
    token = oauth.Token(key=key, secret=secret)
    client = oauth.Client(consumer, token)
    resp, content = client.request( url, method=http_method)
    return content
CONSUMER_KEY = 'L96guHuxCIRxz0quUVCNkHYL7'
CONSUMER_SECRET = 'kSHrrjByp6OyjQM0pFcYTlGE3olASilkIhkBbAuGebZPXGnBVB'
access_token = '806213791-laNuZaMYzd54k9teiqQ8uOgBlP3XO8qxUBF1ebST'
access_secret = 'rU1dp7KTreCXl02mckYVceX8iJmywcG9F95TBYOCzioYW'

# %% [markdown]
# ##The following is the final version of getting info from Twitter API

# %%
home_timeline = oauth_req( 'https://api.twitter.com/1.1/users/search.json?q=Chris&page=1&count=3', access_token, access_secret )

# %%
json.loads(home_timeline)
# Out:
# [{u'contributors_enabled': False,
#   u'created_at': u'Wed Mar 03 21:39:14 +0000 2010',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Official Chris Brown Twitter #XTheAlbum available now! http://t.co/x3IKiOn11q',
#   u'entities': {u'description': {u'urls': [{u'display_url': u'smarturl.it/XTheAlbum?IQid\u2026',
#       u'expanded_url': u'http://smarturl.it/XTheAlbum?IQid=tw',
#       u'indices': [55, 77],
#       u'url': u'http://t.co/x3IKiOn11q'}]},
#    u'url': {u'urls': [{u'display_url': u'chrisbrownworld.com',
#       u'expanded_url': u'http://www.chrisbrownworld.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/GdreIID9ez'}]}},
#   u'favourites_count': 589,
#   u'follow_request_sent': False,
#   u'followers_count': 13775758,
#   u'following': False,
#   u'friends_count': 4,
#   u'geo_enabled': True,
#   u'id': 119509520,
#   u'id_str': u'119509520',
#   u'is_translation_enabled': True,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 46368,
#   u'location': u'',
#   u'name': u'Chris Brown',
#   u'notifications': False,
#   u'profile_background_color': u'999999',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/511907950839877632/ZeEHXWUI.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/511907950839877632/ZeEHXWUI.jpeg',
#   u'profile_background_tile': True,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/119509520/1410840561',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/497420988498198528/EjB-W5lb_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/497420988498198528/EjB-W5lb_normal.jpeg',
#   u'profile_link_color': u'0A0101',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'000000',
#   u'profile_sidebar_fill_color': u'D0D8D9',
#   u'profile_text_color': u'4327E6',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'chrisbrown',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 14:51:43 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [0, 11], u'text': u'TeamBreezy'},
#      {u'indices': [49, 57], u'text': u'BTSTour'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 83528351,
#       u'id_str': u'83528351',
#       u'indices': [19, 26],
#       u'name': u'CHARLIE BROWN',
#       u'screen_name': u'TBWRLD'}]},
#    u'favorite_count': 1202,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539069266658463744,
#    u'id_str': u'539069266658463744',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 743,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'#TeamBreezy follow @TBWRLD for all the exclusive #BTSTour contests leading up to the tour.',
#    u'truncated': False},
#   u'statuses_count': 1784,
#   u'time_zone': u'Hawaii',
#   u'url': u'http://t.co/GdreIID9ez',
#   u'utc_offset': -36000,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Wed Apr 11 16:43:58 +0000 2007',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Host of All In with Chris Hayes on MSNBC, Weeknights at 8pm. Editor at Large at The Nation. Cubs fan.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'allin.msnbc.com',
#       u'expanded_url': u'http://allin.msnbc.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/1Wz5MmBtpw'}]}},
#   u'favourites_count': 230,
#   u'follow_request_sent': False,
#   u'followers_count': 395641,
#   u'following': False,
#   u'friends_count': 714,
#   u'geo_enabled': False,
#   u'id': 4207961,
#   u'id_str': u'4207961',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 9940,
#   u'location': u'Brooklyn',
#   u'name': u'Christopher Hayes',
#   u'notifications': False,
#   u'profile_background_color': u'9AE4E8',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/552711304/tote_twitterskin.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/552711304/tote_twitterskin.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/4207961/1412600167',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/1499446228/MSNBC_Headshot_normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1499446228/MSNBC_Headshot_normal.jpg',
#   u'profile_link_color': u'0000FF',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'87BC44',
#   u'profile_sidebar_fill_color': u'E0FF92',
#   u'profile_text_color': u'000000',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'chrislhayes',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 22:26:54 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 17106279,
#       u'id_str': u'17106279',
#       u'indices': [3, 11],
#       u'name': u'K.C. Johnson',
#       u'screen_name': u'KCJHoop'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539183818180403200,
#    u'id_str': u'539183818180403200',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 140,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sun Nov 30 22:20:24 +0000 2014',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'favorite_count': 68,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 539182182716407808,
#     u'id_str': u'539182182716407808',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 140,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'Bulls are now 5-0 with their regular lineup. Also have played a league-high 12 road games and 9-3.',
#     u'truncated': False},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'RT @KCJHoop: Bulls are now 5-0 with their regular lineup. Also have played a league-high 12 road games and 9-3.',
#    u'truncated': False},
#   u'statuses_count': 46758,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'http://t.co/1Wz5MmBtpw',
#   u'utc_offset': -18000,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Tue Jul 18 21:58:18 +0000 2006',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Husband, Father,Brother, Friend. San Jose FC coach, REALTOR',
#   u'entities': {u'description': {u'urls': []}},
#   u'favourites_count': 15,
#   u'follow_request_sent': False,
#   u'followers_count': 8874,
#   u'following': False,
#   u'friends_count': 222,
#   u'geo_enabled': True,
#   u'id': 2442,
#   u'id_str': u'2442',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 94,
#   u'location': u'San Jose, California',
#   u'name': u'Chris',
#   u'notifications': False,
#   u'profile_background_color': u'8B542B',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2442/1379478584',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/466799618098233344/IxhdLP4x_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/466799618098233344/IxhdLP4x_normal.jpeg',
#   u'profile_link_color': u'9D582E',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'D9B17E',
#   u'profile_sidebar_fill_color': u'EADEAA',
#   u'profile_text_color': u'322929',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'chris',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Wed Oct 15 19:56:31 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [142, 143], u'text': u'Quakes74'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'bit.ly/1wHF2Ew',
#       u'expanded_url': u'http://bit.ly/1wHF2Ew',
#       u'indices': [142, 143],
#       u'url': u'http://t.co/mCV8SNnsqi'}],
#     u'user_mentions': [{u'id': 16303450,
#       u'id_str': u'16303450',
#       u'indices': [3, 17],
#       u'name': u'San Jose Earthquakes',
#       u'screen_name': u'SJEarthquakes'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 522476132969353216,
#    u'id_str': u'522476132969353216',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 91,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Wed Oct 15 16:47:39 +0000 2014',
#     u'entities': {u'hashtags': [{u'indices': [128, 137],
#        u'text': u'Quakes74'}],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'bit.ly/1wHF2Ew',
#        u'expanded_url': u'http://bit.ly/1wHF2Ew',
#        u'indices': [105, 127],
#        u'url': u'http://t.co/mCV8SNnsqi'}],
#      u'user_mentions': []},
#     u'favorite_count': 58,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 522428599685500928,
#     u'id_str': u'522428599685500928',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'lang': u'en',
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 91,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u"NEWS: Quakes announce Dominic Kinnear to return as club's head coach at conclusion of 2014 season---&gt; http://t.co/mCV8SNnsqi #Quakes74",
#     u'truncated': False},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"RT @SJEarthquakes: NEWS: Quakes announce Dominic Kinnear to return as club's head coach at conclusion of 2014 season---&gt; http://t.co/mCV8SN\u2026",
#    u'truncated': False},
#   u'statuses_count': 1017,
#   u'time_zone': u'Pacific Time (US & Canada)',
#   u'url': None,
#   u'utc_offset': -28800,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Wed Jul 15 12:27:21 +0000 2009',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Network engineer converted to Social Anthropology and Data Science\u2014Translator\u2014Logophile\u2014Cartophile\u2014Retephile\u2014@mentions deputy of @christopher.s all over',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'linkd.in/ChristopherAki\u2026',
#       u'expanded_url': u'http://linkd.in/ChristopherAkiki',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/vqWRJUueFl'}]}},
#   u'favourites_count': 5330,
#   u'follow_request_sent': False,
#   u'followers_count': 4151,
#   u'following': False,
#   u'friends_count': 375,
#   u'geo_enabled': True,
#   u'id': 57001957,
#   u'id_str': u'57001957',
#   u'is_translation_enabled': False,
#   u'is_translator': True,
#   u'lang': u'de',
#   u'listed_count': 54,
#   u'location': u'Leipzig, DE',
#   u'name': u'Christopher C. Akiki',
#   u'notifications': False,
#   u'profile_background_color': u'131516',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000073761250/89dd8d2b55548d1c0e4ecbdb31827904.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000073761250/89dd8d2b55548d1c0e4ecbdb31827904.jpeg',
#   u'profile_background_tile': False,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/537514147835949056/e80JT3j3_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/537514147835949056/e80JT3j3_normal.png',
#   u'profile_link_color': u'000000',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'EFEFEF',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'christopher',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Nov 27 19:39:18 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'wolframalpha.com/input/?i=amun-\u2026',
#       u'expanded_url': u'http://www.wolframalpha.com/input/?i=amun-ra',
#       u'indices': [37, 59],
#       u'url': u'http://t.co/92WBXB1iWD'}],
#     u'user_mentions': [{u'id': 523216510,
#       u'id_str': u'523216510',
#       u'indices': [0, 16],
#       u'name': u'Martin John Hadley',
#       u'screen_name': u'martinjhnhadley'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 538054478616727552,
#    u'id_str': u'538054478616727552',
#    u'in_reply_to_screen_name': u'martinjhnhadley',
#    u'in_reply_to_status_id': 538053721281019904,
#    u'in_reply_to_status_id_str': u'538053721281019904',
#    u'in_reply_to_user_id': 523216510,
#    u'in_reply_to_user_id_str': u'523216510',
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'@martinjhnhadley Egyptian mythology. http://t.co/92WBXB1iWD (I think I might have contributed some content to that entry.)',
#    u'truncated': False},
#   u'statuses_count': 4993,
#   u'time_zone': u'Budapest',
#   u'url': u'http://t.co/vqWRJUueFl',
#   u'utc_offset': 3600,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Mon Nov 21 20:08:28 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'no words... ACTIONS.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'Facebook.com/DELACAMPACHRIS\u2026',
#       u'expanded_url': u'http://Facebook.com/DELACAMPACHRISTIAN',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/uIUtV22gW7'}]}},
#   u'favourites_count': 9112,
#   u'follow_request_sent': False,
#   u'followers_count': 23183,
#   u'following': False,
#   u'friends_count': 263,
#   u'geo_enabled': False,
#   u'id': 418133530,
#   u'id_str': u'418133530',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 86,
#   u'location': u'MIAMI FLORIDA - MEXICO CITY',
#   u'name': u'CHRIS',
#   u'notifications': False,
#   u'profile_background_color': u'1A1B1F',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/644814072/mlk6ksl1glbz5ujkdktd.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/644814072/mlk6ksl1glbz5ujkdktd.jpeg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/418133530/1416420902',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/535158770805243905/-3xvu1sj_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/535158770805243905/-3xvu1sj_normal.jpeg',
#   u'profile_link_color': u'2FC2EF',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'181A1E',
#   u'profile_sidebar_fill_color': u'252429',
#   u'profile_text_color': u'666666',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'CHRISDELACAMPA',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 18:18:23 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 958156806,
#       u'id_str': u'958156806',
#       u'indices': [3, 14],
#       u'name': u'To be Honest',
#       u'screen_name': u'BaeFeeling'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539121277601325056,
#    u'id_str': u'539121277601325056',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 14695,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sun Oct 19 23:30:40 +0000 2014',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'favorite_count': 11558,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 523979574632132608,
#     u'id_str': u'523979574632132608',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 14695,
#     u'retweeted': False,
#     u'source': u'<a href="http://twuffer.com" rel="nofollow">Twuffer</a>',
#     u'text': u"Sometimes you can't explain what you feel for a person",
#     u'truncated': False},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"RT @BaeFeeling: Sometimes you can't explain what you feel for a person",
#    u'truncated': False},
#   u'statuses_count': 6171,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'http://t.co/uIUtV22gW7',
#   u'utc_offset': -18000,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Mon May 14 16:23:02 +0000 2012',
#   u'default_profile': True,
#   u'default_profile_image': False,
#   u'description': u'The Official Chris Evans Twitter Page',
#   u'entities': {u'description': {u'urls': []}},
#   u'favourites_count': 0,
#   u'follow_request_sent': False,
#   u'followers_count': 1532550,
#   u'following': False,
#   u'friends_count': 56,
#   u'geo_enabled': False,
#   u'id': 580097412,
#   u'id_str': u'580097412',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 5747,
#   u'location': u'LA',
#   u'name': u'Chris Evans',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_tile': False,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/2224543421/Chris_Evans_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2224543421/Chris_Evans_normal.png',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'C0DEED',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'ChrisEvans',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Nov 27 14:44:20 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 8113,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 537980244939259904,
#    u'id_str': u'537980244939259904',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 3245,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u"Happy Thanksgiving, everyone! I'm truly thankful for the countless blessings in my life. Wishing you all love and happiness today!!",
#    u'truncated': False},
#   u'statuses_count': 136,
#   u'time_zone': u'Arizona',
#   u'url': None,
#   u'utc_offset': -25200,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Wed Mar 21 17:01:19 +0000 2007',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Technology columnist at @WSJ. Texan.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'topics.wsj.com/person/A/biogr\u2026',
#       u'expanded_url': u'http://topics.wsj.com/person/A/biography/8003',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/NsTNW2Ju2G'}]}},
#   u'favourites_count': 28237,
#   u'follow_request_sent': False,
#   u'followers_count': 31418,
#   u'following': False,
#   u'friends_count': 4735,
#   u'geo_enabled': True,
#   u'id': 1769191,
#   u'id_str': u'1769191',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 1968,
#   u'location': u'Baltimore, NYC',
#   u'name': u'Christopher Mims',
#   u'notifications': False,
#   u'profile_background_color': u'FFFFFF',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/603461699/m1zpjg7frrz7qa51e7ad.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/603461699/m1zpjg7frrz7qa51e7ad.jpeg',
#   u'profile_background_tile': True,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1769191/1354880503',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/464049016552972289/xb0Y0hJO_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/464049016552972289/xb0Y0hJO_normal.jpeg',
#   u'profile_link_color': u'0000FF',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'E0FF92',
#   u'profile_text_color': u'000000',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'mims',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 22:09:38 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 35304791,
#       u'id_str': u'35304791',
#       u'indices': [0, 10],
#       u'name': u'Razib Khan',
#       u'screen_name': u'razibkhan'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539179471715442688,
#    u'id_str': u'539179471715442688',
#    u'in_reply_to_screen_name': u'razibkhan',
#    u'in_reply_to_status_id': 539178803755376642,
#    u'in_reply_to_status_id_str': u'539178803755376642',
#    u'in_reply_to_user_id': 35304791,
#    u'in_reply_to_user_id_str': u'35304791',
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'@razibkhan reminds me of the story my dad (born 1944) trots out on occasion, about the first time he saw a TV',
#    u'truncated': False},
#   u'statuses_count': 57311,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'http://t.co/NsTNW2Ju2G',
#   u'utc_offset': -18000,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Fri Jan 14 22:11:56 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Official Chris Rock Twitter account.\r\n\r\n#TopFiveMovie In theaters December 12th!',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'chrisrock.com',
#       u'expanded_url': u'http://www.chrisrock.com/',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/IH38kRvPia'}]}},
#   u'favourites_count': 12,
#   u'follow_request_sent': False,
#   u'followers_count': 2947250,
#   u'following': False,
#   u'friends_count': 97,
#   u'geo_enabled': False,
#   u'id': 238319766,
#   u'id_str': u'238319766',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 10725,
#   u'location': u'New York, NY',
#   u'name': u'Chris Rock',
#   u'notifications': False,
#   u'profile_background_color': u'131516',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/530369924791681026/TdzE8y0W.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/530369924791681026/TdzE8y0W.jpeg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/238319766/1417037779',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/530030424236376064/KdMcs8Km_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/530030424236376064/KdMcs8Km_normal.jpeg',
#   u'profile_link_color': u'DD2E44',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'EFEFEF',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'chrisrock',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 20:30:02 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'whosay.com/l/fAs9KlI',
#       u'expanded_url': u'http://www.whosay.com/l/fAs9KlI',
#       u'indices': [18, 40],
#       u'url': u'http://t.co/iQ1TAAjFEj'}],
#     u'user_mentions': []},
#    u'favorite_count': 61,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539154405803966465,
#    u'id_str': u'539154405803966465',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 35,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.whosay.com" rel="nofollow">WhoSay</a>',
#    u'text': u"That'll show him. http://t.co/iQ1TAAjFEj",
#    u'truncated': False},
#   u'statuses_count': 804,
#   u'time_zone': u'Pacific Time (US & Canada)',
#   u'url': u'http://t.co/IH38kRvPia',
#   u'utc_offset': -28800,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Sun Jun 06 00:24:22 +0000 2010',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u"Rev Chris Oyakhilome, PhD. President of Believers' Loveworld Inc. aka Christ Embassy Int'l. Pastor, teacher, healing minister, TV host and bestselling author",
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'christembassy.org',
#       u'expanded_url': u'http://www.christembassy.org',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/V79GS0HddZ'}]}},
#   u'favourites_count': 1,
#   u'follow_request_sent': False,
#   u'followers_count': 1351391,
#   u'following': False,
#   u'friends_count': 0,
#   u'geo_enabled': False,
#   u'id': 152442703,
#   u'id_str': u'152442703',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 2532,
#   u'location': u'Africa',
#   u'name': u'Pastor Chris ',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/160282014/TWITTER_PAGEa.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/160282014/TWITTER_PAGEa.jpg',
#   u'profile_background_tile': False,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/964600622/CANADA_normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/964600622/CANADA_normal.jpg',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'C0DEED',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'PastorChrisLive',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Thu Nov 27 09:07:10 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'yookos.com/community/past\u2026',
#       u'expanded_url': u'https://www.yookos.com/community/pastorchrislive/blog/2014/11/27/a-tree-planted-by-the-water',
#       u'indices': [2, 25],
#       u'url': u'https://t.co/ui75ZU1xv8'}],
#     u'user_mentions': []},
#    u'favorite_count': 10,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 537895395352129536,
#    u'id_str': u'537895395352129536',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'und',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 25,
#    u'retweeted': False,
#    u'source': u'<a href="https://yookos-login.hub.loginradius.com" rel="nofollow">Yookos-App</a>',
#    u'text': u'- https://t.co/ui75ZU1xv8',
#    u'truncated': False},
#   u'statuses_count': 1535,
#   u'time_zone': u'Greenland',
#   u'url': u'http://t.co/V79GS0HddZ',
#   u'utc_offset': -10800,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Wed Feb 27 03:19:33 +0000 2013',
#   u'default_profile': True,
#   u'default_profile_image': False,
#   u'description': u'im Chris im 1/8 and the Irish one in @StereoKicks AKA Smiley kick. X Factor 2014. now lets have fun do stupid s*#t and get in trouble :D #StereoKicksArmy',
#   u'entities': {u'description': {u'urls': []}},
#   u'favourites_count': 2145,
#   u'follow_request_sent': False,
#   u'followers_count': 95257,
#   u'following': False,
#   u'friends_count': 607,
#   u'geo_enabled': True,
#   u'id': 1223524129,
#   u'id_str': u'1223524129',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 452,
#   u'location': u'Co.Meath Ireland ',
#   u'name': u'Chris Leonard',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1223524129/1416876863',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/539069341661417472/Cc24j8C1_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/539069341661417472/Cc24j8C1_normal.jpeg',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'C0DEED',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'ChrisOfficial_',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 21:19:10 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 3079,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539166774370250752,
#    u'id_str': u'539166774370250752',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 2309,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"I'm honoured too have stood on the X factor stage with 7 of my best mates! thanks to all of you its thanks to you we've come this far \u2764\ufe0f xxx",
#    u'truncated': False},
#   u'statuses_count': 11345,
#   u'time_zone': u'Dublin',
#   u'url': None,
#   u'utc_offset': 0,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Wed Jul 30 21:20:18 +0000 2008',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Stand-upper, Zombie Therapist, Talking Snake and POINTS giver',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'nerdist.com',
#       u'expanded_url': u'http://www.nerdist.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/WmKtIZV83l'}]}},
#   u'favourites_count': 667,
#   u'follow_request_sent': False,
#   u'followers_count': 2446040,
#   u'following': False,
#   u'friends_count': 657,
#   u'geo_enabled': False,
#   u'id': 15666380,
#   u'id_str': u'15666380',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 21301,
#   u'location': u'Lawss Angleez',
#   u'name': u'Chris Hardwick',
#   u'notifications': False,
#   u'profile_background_color': u'ECDFCE',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/23601674/Nerdist_Twitter_Bkgrnd.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/23601674/Nerdist_Twitter_Bkgrnd.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/15666380/1354994055',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/489572042815967232/Hq8pfyEx_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489572042815967232/Hq8pfyEx_normal.jpeg',
#   u'profile_link_color': u'BA494D',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'BA494D',
#   u'profile_sidebar_fill_color': u'83989D',
#   u'profile_text_color': u'1F3C4C',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'nerdist',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 21:59:57 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 857271295,
#       u'id_str': u'857271295',
#       u'indices': [0, 14],
#       u'name': u'Keith',
#       u'screen_name': u'Blazer24Seven'}]},
#    u'favorite_count': 5,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539177035713617920,
#    u'id_str': u'539177035713617920',
#    u'in_reply_to_screen_name': u'Blazer24Seven',
#    u'in_reply_to_status_id': 539176676848967680,
#    u'in_reply_to_status_id_str': u'539176676848967680',
#    u'in_reply_to_user_id': 857271295,
#    u'in_reply_to_user_id_str': u'857271295',
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for i\u039fS</a>',
#    u'text': u'@Blazer24Seven get back to me after the episode, sport.',
#    u'truncated': False},
#   u'statuses_count': 24155,
#   u'time_zone': u'Pacific Time (US & Canada)',
#   u'url': u'http://t.co/WmKtIZV83l',
#   u'utc_offset': -28800,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Sun Jun 07 23:42:47 +0000 2009',
#   u'default_profile': True,
#   u'default_profile_image': False,
#   u'description': u"World Boss / 'Chris Lion'",
#   u'entities': {u'description': {u'urls': []}},
#   u'favourites_count': 7,
#   u'follow_request_sent': False,
#   u'followers_count': 1806969,
#   u'following': False,
#   u'friends_count': 45,
#   u'geo_enabled': False,
#   u'id': 45452226,
#   u'id_str': u'45452226',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 3477,
#   u'location': u'',
#   u'name': u'Chris Gayle',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_background_tile': False,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/3424429800/9986e99d0b136032cb32c5190fac348c_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/3424429800/9986e99d0b136032cb32c5190fac348c_normal.jpeg',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'C0DEED',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'henrygayle',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Nov 29 16:25:15 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [15, 19], u'text': u'RVP'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 216299334,
#       u'id_str': u'216299334',
#       u'indices': [35, 47],
#       u'name': u'Piers Morgan',
#       u'screen_name': u'piersmorgan'}]},
#    u'favorite_count': 153,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 538730420343701504,
#    u'id_str': u'538730420343701504',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 111,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'What a beauty. #RVP  Goal number 5 @piersmorgan',
#    u'truncated': False},
#   u'statuses_count': 9995,
#   u'time_zone': u'Mountain Time (US & Canada)',
#   u'url': None,
#   u'utc_offset': -25200,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Thu Mar 03 10:40:31 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u"Former member of Stanley Marsh 3's Dynamite Museum, born and raised in The Children of God, Christopher Owens is an American Song Writer born in 1979.",
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'christopherowensonline.com',
#       u'expanded_url': u'http://www.christopherowensonline.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/XjOdI7C7xo'}]}},
#   u'favourites_count': 10,
#   u'follow_request_sent': False,
#   u'followers_count': 20955,
#   u'following': False,
#   u'friends_count': 100,
#   u'geo_enabled': False,
#   u'id': 260176078,
#   u'id_str': u'260176078',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 360,
#   u'location': u'San Francisco',
#   u'name': u'Christopher Owens',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/244857128/Space_Immense_space_015325_.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/244857128/Space_Immense_space_015325_.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/260176078/1408751629',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/524021410897743872/Apz-a5ry_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/524021410897743872/Apz-a5ry_normal.jpeg',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': False,
#   u'protected': False,
#   u'screen_name': u'Chri55yBaby',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Nov 29 23:09:58 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 513764510,
#       u'id_str': u'513764510',
#       u'indices': [0, 13],
#       u'name': u'Juan Limbo',
#       u'screen_name': u'juanm_artero'}]},
#    u'favorite_count': 1,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 538832266948919296,
#    u'id_str': u'538832266948919296',
#    u'in_reply_to_screen_name': u'juanm_artero',
#    u'in_reply_to_status_id': 538794675818491904,
#    u'in_reply_to_status_id_str': u'538794675818491904',
#    u'in_reply_to_user_id': 513764510,
#    u'in_reply_to_user_id_str': u'513764510',
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 1,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'@juanm_artero Same one! Good eye',
#    u'truncated': False},
#   u'statuses_count': 6608,
#   u'time_zone': None,
#   u'url': u'http://t.co/XjOdI7C7xo',
#   u'utc_offset': None,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Wed Oct 21 06:21:23 +0000 2009',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Christopher Hitchens Official Twitter Page',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'theologian.tv/2010/03/christ\u2026',
#       u'expanded_url': u'http://theologian.tv/2010/03/christopher-hitchens-on-q-tv/',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/yhq0xyRjpt'}]}},
#   u'favourites_count': 0,
#   u'follow_request_sent': False,
#   u'followers_count': 21632,
#   u'following': False,
#   u'friends_count': 2956,
#   u'geo_enabled': True,
#   u'id': 84015988,
#   u'id_str': u'84015988',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 472,
#   u'location': u'',
#   u'name': u'Christopher Hitchens',
#   u'notifications': False,
#   u'profile_background_color': u'0A0A0A',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/84788807/bgtwitter.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/84788807/bgtwitter.jpg',
#   u'profile_background_tile': True,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/765010777/Christopher-Hitchens-001_1__normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/765010777/Christopher-Hitchens-001_1__normal.jpg',
#   u'profile_link_color': u'800D0D',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'0D000D',
#   u'profile_sidebar_fill_color': u'262626',
#   u'profile_text_color': u'757575',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'ChrisHitchens',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Mar 21 05:01:48 +0000 2010',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 12,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 10807411053,
#    u'id_str': u'10807411053',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 14,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Christopher Hitchens on QTV:\nhttp://theologian.tv/2010/03/christopher-hitchens-on-q-tv/',
#    u'truncated': False},
#   u'statuses_count': 10,
#   u'time_zone': u'Central Time (US & Canada)',
#   u'url': u'http://t.co/yhq0xyRjpt',
#   u'utc_offset': -21600,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Fri Feb 05 18:54:42 +0000 2010',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Adweek Digital Editor - Cornhusker in Brooklyn. Email christopher(dot)heine(at)adweek(dot)com',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'adweek.com',
#       u'expanded_url': u'http://adweek.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/9PQ2MCc1u0'}]}},
#   u'favourites_count': 538,
#   u'follow_request_sent': False,
#   u'followers_count': 6049,
#   u'following': False,
#   u'friends_count': 994,
#   u'geo_enabled': True,
#   u'id': 111666041,
#   u'id_str': u'111666041',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 332,
#   u'location': u'Astor Place - BKLYN',
#   u'name': u'Christopher Heine',
#   u'notifications': False,
#   u'profile_background_color': u'9AE4E8',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/831800732/f38747b2fecef6340b2643ff1c12996b.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/831800732/f38747b2fecef6340b2643ff1c12996b.jpeg',
#   u'profile_background_tile': True,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/412661587900510208/HRxF9GLl_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/412661587900510208/HRxF9GLl_normal.jpeg',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'000000',
#   u'profile_sidebar_fill_color': u'DDFFCC',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'Chris_Heine',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 23 06:05:38 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 536400158066769920,
#    u'id_str': u'536400158066769920',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Watching MWC football late Saturday night is like watching the CFL if it resonated about, well, 90 percent more. Canuck pro FB is a mystery.',
#    u'truncated': False},
#   u'statuses_count': 4719,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'http://t.co/9PQ2MCc1u0',
#   u'utc_offset': -18000,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Fri Jan 23 17:48:36 +0000 2009',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'The Official Chris Cornell Twitter',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'chriscornell.com',
#       u'expanded_url': u'http://www.chriscornell.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/AvYmMjPmwW'}]}},
#   u'favourites_count': 35,
#   u'follow_request_sent': False,
#   u'followers_count': 1826061,
#   u'following': False,
#   u'friends_count': 381,
#   u'geo_enabled': False,
#   u'id': 19404587,
#   u'id_str': u'19404587',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 11619,
#   u'location': u'',
#   u'name': u'Chris Cornell',
#   u'notifications': False,
#   u'profile_background_color': u'000000',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/352217394/Cornell500.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/352217394/Cornell500.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/19404587/1357574953',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/1604728194/Cornell500_normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1604728194/Cornell500_normal.jpg',
#   u'profile_link_color': u'1F98C7',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'C6E2EE',
#   u'profile_sidebar_fill_color': u'DAECF4',
#   u'profile_text_color': u'663B12',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'chriscornell',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
# ...
#       u'media_url': u'http://pbs.twimg.com/media/B3YxRn_CQAAUrVy.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3YxRn_CQAAUrVy.jpg',
#       u'sizes': {u'large': {u'h': 404, u'resize': u'fit', u'w': 404},
#        u'medium': {u'h': 404, u'resize': u'fit', u'w': 404},
#        u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/5qv2XrrBvc'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'chriscornellstore.com',
#       u'expanded_url': u'http://www.chriscornellstore.com',
#       u'indices': [72, 94],
#       u'url': u'http://t.co/vMxBXEP17n'}],
#     u'user_mentions': []},
#    u'favorite_count': 39,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 538331567274209280,
#    u'id_str': u'538331567274209280',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 35,
#    u'retweeted': False,
#    u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    u'text': u'Black Friday \u2013 Cyber Monday free shipping on all orders (+ fine print)  http://t.co/vMxBXEP17n http://t.co/5qv2XrrBvc',
#    u'truncated': False},
#   u'statuses_count': 3078,
#   u'time_zone': u'Pacific Time (US & Canada)',
#   u'url': u'http://t.co/AvYmMjPmwW',
#   u'utc_offset': -28800,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Sun Apr 26 07:21:45 +0000 2009',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u"I'm Christopher Sabat and my voice is having sex with your girlfriend.",
#   u'entities': {u'description': {u'urls': []}},
#   u'favourites_count': 770,
#   u'follow_request_sent': False,
#   u'followers_count': 18376,
#   u'following': False,
#   u'friends_count': 297,
#   u'geo_enabled': True,
#   u'id': 35425166,
#   u'id_str': u'35425166',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 189,
#   u'location': u'Dallas, Texas',
#   u'name': u'Christopher Sabat',
#   u'notifications': False,
#   u'profile_background_color': u'1A1B1F',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/35425166/1380503917',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/1109491433/space_face_normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1109491433/space_face_normal.jpg',
#   u'profile_link_color': u'2FC2EF',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'181A1E',
#   u'profile_sidebar_fill_color': u'252429',
#   u'profile_text_color': u'666666',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'Chris24_Sabat',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 10:47:21 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'media': [{u'display_url': u'pic.twitter.com/6cDqfs5h2S',
#       u'expanded_url': u'http://twitter.com/Chris24_Sabat/status/539007769635213312/photo/1',
#       u'id': 539007764266512384,
#       u'id_str': u'539007764266512384',
#       u'indices': [41, 63],
#       u'media_url': u'http://pbs.twimg.com/media/B3rwtLBIcAAPQqT.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3rwtLBIcAAPQqT.jpg',
#       u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 824},
#        u'medium': {u'h': 745, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 422, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/6cDqfs5h2S'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 551583930,
#       u'id_str': u'551583930',
#       u'indices': [0, 16],
#       u'name': u'Brittany Leigh Smith',
#       u'screen_name': u'BritSmithereens'},
#      {u'id': 362035775,
#       u'id_str': u'362035775',
#       u'indices': [17, 26],
#       u'name': u'Will Abbott',
#       u'screen_name': u'wabbott9'},
#      {u'id': 14167540,
#       u'id_str': u'14167540',
#       u'indices': [27, 40],
#       u'name': u'John Kovalic',
#       u'screen_name': u'muskrat_john'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539007769635213312,
#    u'id_str': u'539007769635213312',
#    u'in_reply_to_screen_name': u'BritSmithereens',
#    u'in_reply_to_status_id': 538956404678463489,
#    u'in_reply_to_status_id_str': u'538956404678463489',
#    u'in_reply_to_user_id': 551583930,
#    u'in_reply_to_user_id_str': u'551583930',
#    u'lang': u'und',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'@BritSmithereens @wabbott9 @muskrat_john http://t.co/6cDqfs5h2S',
#    u'truncated': False},
#   u'statuses_count': 1645,
#   u'time_zone': u'Central Time (US & Canada)',
#   u'url': None,
#   u'utc_offset': -21600,
#   u'verified': False},
#  {u'contributors_enabled': False,
#   u'created_at': u'Thu Sep 02 18:21:55 +0000 2010',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Canadian Astronaut, back on Earth after living aboard ISS as Commander of Expedition 35. For events and media, please write to requests@chrishadfield.ca.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'chrishadfield.ca',
#       u'expanded_url': u'http://www.chrishadfield.ca',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/lAFAbbMS1D'}]}},
#   u'favourites_count': 1105,
#   u'follow_request_sent': False,
#   u'followers_count': 1193267,
#   u'following': False,
#   u'friends_count': 63,
#   u'geo_enabled': False,
#   u'id': 186154646,
#   u'id_str': u'186154646',
#   u'is_translation_enabled': True,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 9329,
#   u'location': u'Earth',
#   u'name': u'Chris Hadfield',
#   u'notifications': False,
#   u'profile_background_color': u'000000',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/143763280/Small.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/143763280/Small.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/186154646/1398345584',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/462319961998761984/zvO7AYe0_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/462319961998761984/zvO7AYe0_normal.png',
#   u'profile_link_color': u'0084B4',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': False,
#   u'protected': False,
#   u'screen_name': u'Cmdr_Hadfield',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 13:38:53 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'media': [{u'display_url': u'pic.twitter.com/UO6vL3TtzS',
#       u'expanded_url': u'http://twitter.com/Cmdr_Hadfield/status/539050938745774080/photo/1',
#       u'id': 539050937780666368,
#       u'id_str': u'539050937780666368',
#       u'indices': [118, 140],
#       u'media_url': u'http://pbs.twimg.com/media/B3sX-M5CAAAcHxo.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3sX-M5CAAAcHxo.jpg',
#       u'sizes': {u'large': {u'h': 872, u'resize': u'fit', u'w': 1024},
#        u'medium': {u'h': 510, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 289, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/UO6vL3TtzS'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 568,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539050938745774080,
#    u'id_str': u'539050938745774080',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 244,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Nights in shining armour. One has a complicated helmet, the other, elbows. Neither can take a direct meteorite impact http://t.co/UO6vL3TtzS',
#    u'truncated': False},
#   u'statuses_count': 7010,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'http://t.co/lAFAbbMS1D',
#   u'utc_offset': -18000,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Thu Jul 13 09:05:49 +0000 2006',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Married to @crystale, dad to @CCEleven & @CircaLuna, investor in @Twitter, @Uber, @Instagram, @kickstarter & other startups. Learn more: http://t.co/nJWB60dIUL.',
#   u'entities': {u'description': {u'urls': [{u'display_url': u'lowercasecapital.com',
#       u'expanded_url': u'http://lowercasecapital.com/',
#       u'indices': [137, 159],
#       u'url': u'http://t.co/nJWB60dIUL'}]},
#    u'url': {u'urls': [{u'display_url': u'lowercasellc.com/proprietor/',
#       u'expanded_url': u'http://lowercasellc.com/proprietor/',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/1kCMgFFZGy'}]}},
#   u'favourites_count': 87772,
#   u'follow_request_sent': False,
#   u'followers_count': 1503045,
#   u'following': False,
#   u'friends_count': 825,
#   u'geo_enabled': True,
#   u'id': 586,
#   u'id_str': u'586',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 9275,
#   u'location': u'',
#   u'name': u'Chris Sacca',
#   u'notifications': False,
#   u'profile_background_color': u'AABCC3',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/201085969/background_2.jpg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/201085969/background_2.jpg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/586/1398722392',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/1771648774/Sacca_profile_normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1771648774/Sacca_profile_normal.jpg',
#   u'profile_link_color': u'829DA8',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'222222',
#   u'profile_sidebar_fill_color': u'000000',
#   u'profile_text_color': u'666666',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'sacca',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 21:04:34 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/harper/status/\u2026',
#       u'expanded_url': u'https://twitter.com/harper/status/538889966177492992',
#       u'indices': [102, 125],
#       u'url': u'https://t.co/fwrFbAzYdO'}],
#     u'user_mentions': [{u'id': 5699,
#       u'id_str': u'5699',
#       u'indices': [0, 8],
#       u'name': u'Stewart Butterfield',
#       u'screen_name': u'stewart'},
#      {u'id': 1497,
#       u'id_str': u'1497',
#       u'indices': [64, 71],
#       u'name': u'harper',
#       u'screen_name': u'harper'}]},
#    u'favorite_count': 7,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539163100088246272,
#    u'id_str': u'539163100088246272',
#    u'in_reply_to_screen_name': u'stewart',
#    u'in_reply_to_status_id': 539161086088339456,
#    u'in_reply_to_status_id_str': u'539161086088339456',
#    u'in_reply_to_user_id': 5699,
#    u'in_reply_to_user_id_str': u'5699',
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"@stewart Dude, can we first at least take a moment to celebrate @harper's invention of hashtag emoji? https://t.co/fwrFbAzYdO",
#    u'truncated': False},
#   u'statuses_count': 34897,
#   u'time_zone': u'Pacific Time (US & Canada)',
#   u'url': u'http://t.co/1kCMgFFZGy',
#   u'utc_offset': -28800,
#   u'verified': True},
#  {u'contributors_enabled': False,
#   u'created_at': u'Fri Jan 30 10:49:31 +0000 2009',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Official Twitter page of Sir Chris Hoy, 6 x Olympic Champion 11x World Champion track cyclist. Founder of HOYbikes.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'HOYbikes.com',
#       u'expanded_url': u'http://www.HOYbikes.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/gs2co5jXf2'}]}},
#   u'favourites_count': 1519,
#   u'follow_request_sent': False,
#   u'followers_count': 620688,
#   u'following': False,
#   u'friends_count': 615,
#   u'geo_enabled': False,
#   u'id': 19762524,
#   u'id_str': u'19762524',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 2716,
#   u'location': u'Edinburgh / Manchester',
#   u'name': u'Chris Hoy',
#   u'notifications': False,
#   u'profile_background_color': u'131516',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/368279717/securedownload.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/368279717/securedownload.jpeg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/19762524/1412166564',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/3619382117/585ad927e2e9aee1df42c60228f8f401_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/3619382117/585ad927e2e9aee1df42c60228f8f401_normal.jpeg',
#   u'profile_link_color': u'009999',
#   u'profile_location': None,
#   u'profile_sidebar_border_color': u'EEEEEE',
#   u'profile_sidebar_fill_color': u'EFEFEF',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'chrishoy',
#   u'status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Nov 30 20:37:38 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 1000114118,
#       u'id_str': u'1000114118',
#       u'indices': [0, 15],
#       u'name': u'Highland Wagyu',
#       u'screen_name': u'ChapmanMartine'},
#      {u'id': 221977993,
#       u'id_str': u'221977993',
#       u'indices': [16, 30],
#       u'name': u'Mr Highland Wagyu',
#       u'screen_name': u'HighlandWagyu'},
#      {u'id': 299629156,
#       u'id_str': u'299629156',
#       u'indices': [31, 42],
#       u'name': u'Tom Kitchin',
#       u'screen_name': u'TomKitchin'}]},
#    u'favorite_count': 1,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 539156321732661249,
#    u'id_str': u'539156321732661249',
#    u'in_reply_to_screen_name': u'ChapmanMartine',
#    u'in_reply_to_status_id': 539156127276335104,
#    u'in_reply_to_status_id_str': u'539156127276335104',
#    u'in_reply_to_user_id': 1000114118,
#    u'in_reply_to_user_id_str': u'1000114118',
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'@ChapmanMartine @HighlandWagyu @TomKitchin thanks, hopefully see you soon! (Starts car engine..)',
#    u'truncated': False},
#   u'statuses_count': 7735,
#   u'time_zone': u'London',
#   u'url': u'http://t.co/gs2co5jXf2',
#   u'utc_offset': 0,
#   u'verified': True}]
