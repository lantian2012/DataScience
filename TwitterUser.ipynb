# %%
import oauth2 as oauth
import time
import json
#home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', 'abcdefg', 'hijklmnop' )

# %%
CONSUMER_KEY = "ZanES4cy8hufvy2yjTLFG8tbO"
CONSUMER_SECRET = "uSbXql55opsnhzGyUlRngp72ZrjjTDNrtkXRHJZ2nTmJJCQ5Mi"
key = "2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU"
secret = "I7doox0PWs22EUMIqFPnk7SqMDFydethoOOR83Wif954f"

# %%
def oauth_req(url, key, secret, http_method="GET", post_body=None, http_headers=None):
    consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
    token = oauth.Token(key=key, secret=secret)
    client = oauth.Client(consumer, token)
    resp, content = client.request( url, method=http_method, body=post_body, headers=http_headers)
    return content

# %%
url1 = "https://api.twitter.com/1.1/statuses/home_timeline.json"
url2 = "https://api.twitter.com/1.1/users/search.json?amp%3Bcount=3&amp%3Bpage=1&q=Twitter+API"
url3 = "https://stream.twitter.com/1.1/statuses/sample.json"
home_timeline = oauth_req( url2, key, secret )
json.loads(home_timeline)
# Out:
# <oauth2.Client object at 0x104532550>
# {u'errors': [{u'code': 32, u'message': u'Could not authenticate you'}]}

# %%
#home_timeline = oauth_req( 'https://api.twitter.com/1.1/users/search.json?q=&page=1&count=3', key, secret )

# %%
type(home_timeline)
# Out:
# str

# %%
json.loads(home_timeline)
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Nov 25 01:40:17 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/i8iupSlXwG',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/537058157206315009/photo/1',
#      u'id': 537017121130049536,
#      u'id_str': u'537017121130049536',
#      u'indices': [109, 131],
#      u'media_url': u'http://pbs.twimg.com/media/B3PeOfdCcAATo8s.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PeOfdCcAATo8s.jpg',
#      u'sizes': {u'large': {u'h': 512, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 300, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 170, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/i8iupSlXwG'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'on.nba.com/11R8lM5',
#      u'expanded_url': u'http://on.nba.com/11R8lM5',
#      u'indices': [86, 108],
#      u'url': u'http://t.co/eRVblKBqeC'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/i8iupSlXwG',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/537058157206315009/photo/1',
#      u'id': 537017121130049536,
#      u'id_str': u'537017121130049536',
#      u'indices': [109, 131],
#      u'media_url': u'http://pbs.twimg.com/media/B3PeOfdCcAATo8s.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PeOfdCcAATo8s.jpg',
#      u'sizes': {u'large': {u'h': 512, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 300, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 170, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/i8iupSlXwG'}]},
#   u'favorite_count': 11,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537058157206315009,
#   u'id_str': u'537058157206315009',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 8,
#   u'retweeted': False,
#   u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   u'text': u'Our Top 5 Plays from last week has an obvious #1, but you can watch all of them here: http://t.co/eRVblKBqeC http://t.co/i8iupSlXwG',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Nov 10 18:49:37 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter feed of the Atlanta Hawks!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'Hawks.com',
#        u'expanded_url': u'http://Hawks.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/46IXpwg4mo'}]}},
#    u'favourites_count': 280,
#    u'follow_request_sent': False,
#    u'followers_count': 252536,
#    u'following': True,
#    u'friends_count': 5902,
#    u'geo_enabled': True,
#    u'id': 17292143,
#    u'id_str': u'17292143',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 3247,
#    u'location': u'Philips Arena',
#    u'name': u'Atlanta Hawks',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17292143/1414604164',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ATLHawks',
#    u'statuses_count': 34372,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/46IXpwg4mo',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Nov 25 00:43:18 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [45, 67],
#      u'text': u'carreradelasestrellas'}],
#    u'media': [{u'display_url': u'pic.twitter.com/3Twnb5LpzQ',
#      u'expanded_url': u'http://twitter.com/Anibal271277/status/537039975326691328/photo/1',
#      u'id': 537039959111135232,
#      u'id_str': u'537039959111135232',
#      u'indices': [139, 140],
#      u'media_url': u'http://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#      u'sizes': {u'large': {u'h': 683, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 400, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 226, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 537039975326691328,
#      u'source_status_id_str': u'537039975326691328',
#      u'type': u'photo',
#      u'url': u'http://t.co/3Twnb5LpzQ'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 255236595,
#      u'id_str': u'255236595',
#      u'indices': [3, 16],
#      u'name': u'anibal herrera',
#      u'screen_name': u'Anibal271277'},
#     {u'id': 21046818,
#      u'id_str': u'21046818',
#      u'indices': [18, 28],
#      u'name': u'Juan Pablo Montoya',
#      u'screen_name': u'jpmontoya'},
#     {u'id': 423856872,
#      u'id_str': u'423856872',
#      u'indices': [71, 82],
#      u'name': u'Autodromos',
#      u'screen_name': u'Autodromos'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/3Twnb5LpzQ',
#      u'expanded_url': u'http://twitter.com/Anibal271277/status/537039975326691328/photo/1',
#      u'id': 537039959111135232,
#      u'id_str': u'537039959111135232',
#      u'indices': [139, 140],
#      u'media_url': u'http://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#      u'sizes': {u'large': {u'h': 683, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 400, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 226, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 537039975326691328,
#      u'source_status_id_str': u'537039975326691328',
#      u'type': u'photo',
#      u'url': u'http://t.co/3Twnb5LpzQ'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537043816289931264,
#   u'id_str': u'537043816289931264',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'es',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 3,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Tue Nov 25 00:28:02 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [27, 49],
#       u'text': u'carreradelasestrellas'}],
#     u'media': [{u'display_url': u'pic.twitter.com/3Twnb5LpzQ',
#       u'expanded_url': u'http://twitter.com/Anibal271277/status/537039975326691328/photo/1',
#       u'id': 537039959111135232,
#       u'id_str': u'537039959111135232',
#       u'indices': [105, 127],
#       u'media_url': u'http://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#       u'sizes': {u'large': {u'h': 683, u'resize': u'fit', u'w': 1024},
#        u'medium': {u'h': 400, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 226, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/3Twnb5LpzQ'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 21046818,
#       u'id_str': u'21046818',
#       u'indices': [0, 10],
#       u'name': u'Juan Pablo Montoya',
#       u'screen_name': u'jpmontoya'},
#      {u'id': 423856872,
#       u'id_str': u'423856872',
#       u'indices': [53, 64],
#       u'name': u'Autodromos',
#       u'screen_name': u'Autodromos'}]},
#    u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/3Twnb5LpzQ',
#       u'expanded_url': u'http://twitter.com/Anibal271277/status/537039975326691328/photo/1',
#       u'id': 537039959111135232,
#       u'id_str': u'537039959111135232',
#       u'indices': [105, 127],
#       u'media_url': u'http://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3Py_1kCcAAp_Kn.jpg',
#       u'sizes': {u'large': {u'h': 683, u'resize': u'fit', u'w': 1024},
#        u'medium': {u'h': 400, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 226, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/3Twnb5LpzQ'}]},
#    u'favorite_count': 8,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 537039975326691328,
#    u'id_str': u'537039975326691328',
#    u'in_reply_to_screen_name': u'jpmontoya',
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': 21046818,
#    u'in_reply_to_user_id_str': u'21046818',
#    u'lang': u'es',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 3,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>',
#    u'text': u'@jpmontoya, listos para la #carreradelasestrellas en @Autodromos, en padock a ver si consigo aut\xf3grafo.. http://t.co/3Twnb5LpzQ',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Feb 20 23:35:06 +0000 2011',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Profesional, comprometido con las leyes de la f\xedsica cu\xe1ntica.',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 15,
#     u'follow_request_sent': False,
#     u'followers_count': 23,
#     u'following': False,
#     u'friends_count': 68,
#     u'geo_enabled': False,
#     u'id': 255236595,
#     u'id_str': u'255236595',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'es',
#     u'listed_count': 0,
#     u'location': u'',
#     u'name': u'anibal herrera',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/3785995031/022ecab4ca296ce42393abd80e04963b_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/3785995031/022ecab4ca296ce42393abd80e04963b_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_location': None,
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Anibal271277',
#     u'statuses_count': 512,
#     u'time_zone': None,
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @Anibal271277: @jpmontoya, listos para la #carreradelasestrellas en @Autodromos, en padock a ver si consigo aut\xf3grafo.. http://t.co/3Twn\u2026',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Feb 17 00:17:01 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Verizon Team Penske driver. Race winner in F1, Indycar, NASCAR, CART,  and Grand-AM.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'jpmontoya.com',
#        u'expanded_url': u'http://www.jpmontoya.com/',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/Hyoe3wozQs'}]}},
#    u'favourites_count': 419,
#    u'follow_request_sent': False,
#    u'followers_count': 890628,
#    u'following': True,
#    u'friends_count': 193,
#    u'geo_enabled': False,
#    u'id': 21046818,
#    u'id_str': u'21046818',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 9555,
#    u'location': u'Miami',
#    u'name': u'Juan Pablo Montoya',
#    u'notifications': False,
#    u'profile_background_color': u'FFFFFF',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/516175288951009280/OFmI3XX4.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/516175288951009280/OFmI3XX4.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/21046818/1399337388',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/471243745262698496/F4dHBjBs_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/471243745262698496/F4dHBjBs_normal.jpeg',
#    u'profile_link_color': u'DD2E44',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'C30000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'jpmontoya',
#    u'statuses_count': 8093,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/Hyoe3wozQs',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Nov 25 00:37:09 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1Flczrt',
#      u'expanded_url': u'http://bit.ly/1Flczrt',
#      u'indices': [83, 105],
#      u'url': u'http://t.co/H4xZrtStyB'}],
#    u'user_mentions': [{u'id': 132349189,
#      u'id_str': u'132349189',
#      u'indices': [33, 44],
#      u'name': u'Jessica Taylor',
#      u'screen_name': u'JesMTaylor'}]},
#   u'favorite_count': 22,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537042270164246528,
#   u'id_str': u'537042270164246528',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 11,
#   u'retweeted': False,
#   u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   u'text': u'Amazing!\n\n5\'4" Hawks TV reporter @JesMTaylor throws down a MONSTER one-handed jam: http://t.co/H4xZrtStyB',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Nov 10 18:49:37 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter feed of the Atlanta Hawks!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'Hawks.com',
#        u'expanded_url': u'http://Hawks.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/46IXpwg4mo'}]}},
#    u'favourites_count': 280,
#    u'follow_request_sent': False,
#    u'followers_count': 252536,
#    u'following': True,
#    u'friends_count': 5902,
#    u'geo_enabled': True,
#    u'id': 17292143,
#    u'id_str': u'17292143',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 3247,
#    u'location': u'Philips Arena',
#    u'name': u'Atlanta Hawks',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17292143/1414604164',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ATLHawks',
#    u'statuses_count': 34372,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/46IXpwg4mo',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 23:43:26 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [50, 72],
#      u'text': u'CarreraDeLasEstrellas'}],
#    u'media': [{u'display_url': u'pic.twitter.com/MWVD3ivmJe',
#      u'expanded_url': u'http://twitter.com/MaktiusHerrera/status/537021095736782850/photo/1',
#      u'id': 537021094449127424,
#      u'id_str': u'537021094449127424',
#      u'indices': [112, 134],
#      u'media_url': u'http://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#      u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 537021095736782850,
#      u'source_status_id_str': u'537021095736782850',
#      u'type': u'photo',
#      u'url': u'http://t.co/MWVD3ivmJe'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 1138704794,
#      u'id_str': u'1138704794',
#      u'indices': [3, 18],
#      u'name': u'MateoHerrera',
#      u'screen_name': u'MaktiusHerrera'},
#     {u'id': 21046818,
#      u'id_str': u'21046818',
#      u'indices': [38, 48],
#      u'name': u'Juan Pablo Montoya',
#      u'screen_name': u'jpmontoya'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/MWVD3ivmJe',
#      u'expanded_url': u'http://twitter.com/MaktiusHerrera/status/537021095736782850/photo/1',
#      u'id': 537021094449127424,
#      u'id_str': u'537021094449127424',
#      u'indices': [112, 134],
#      u'media_url': u'http://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#      u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 537021095736782850,
#      u'source_status_id_str': u'537021095736782850',
#      u'type': u'photo',
#      u'url': u'http://t.co/MWVD3ivmJe'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537028750593261568,
#   u'id_str': u'537028750593261568',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'es',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 4,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Nov 24 23:13:01 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [30, 52],
#       u'text': u'CarreraDeLasEstrellas'}],
#     u'media': [{u'display_url': u'pic.twitter.com/MWVD3ivmJe',
#       u'expanded_url': u'http://twitter.com/MaktiusHerrera/status/537021095736782850/photo/1',
#       u'id': 537021094449127424,
#       u'id_str': u'537021094449127424',
#       u'indices': [92, 114],
#       u'media_url': u'http://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#       u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 1024},
#        u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/MWVD3ivmJe'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 21046818,
#       u'id_str': u'21046818',
#       u'indices': [18, 28],
#       u'name': u'Juan Pablo Montoya',
#       u'screen_name': u'jpmontoya'}]},
#    u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/MWVD3ivmJe',
#       u'expanded_url': u'http://twitter.com/MaktiusHerrera/status/537021095736782850/photo/1',
#       u'id': 537021094449127424,
#       u'id_str': u'537021094449127424',
#       u'indices': [92, 114],
#       u'media_url': u'http://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/B3Ph1xOIIAA0Jxk.jpg',
#       u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 1024},
#        u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/MWVD3ivmJe'}]},
#    u'favorite_count': 13,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 537021095736782850,
#    u'id_str': u'537021095736782850',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'es',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 4,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>',
#    u'text': u'Faltan pocos dias @jpmontoya  #CarreraDeLasEstrellas!\U0001f601 \r\r*Por primera vez vere a mi \xeddolo!\U0001f602 http://t.co/MWVD3ivmJe',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Feb 01 04:30:27 +0000 2013',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 28,
#     u'follow_request_sent': False,
#     u'followers_count': 29,
#     u'following': False,
#     u'friends_count': 35,
#     u'geo_enabled': False,
#     u'id': 1138704794,
#     u'id_str': u'1138704794',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'es',
#     u'listed_count': 0,
#     u'location': u'Barrancabermeja',
#     u'name': u'MateoHerrera',
#     u'notifications': False,
#     u'profile_background_color': u'000000',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000074312262/75fd637e5d796ec1cb3ca86da1807808.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000074312262/75fd637e5d796ec1cb3ca86da1807808.jpeg',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1138704794/1416870438',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/537019816360833025/MKik5R8L_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/537019816360833025/MKik5R8L_normal.jpeg',
#     u'profile_link_color': u'050505',
#     u'profile_location': None,
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'MaktiusHerrera',
#     u'statuses_count': 116,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'url': None,
#     u'utc_offset': -18000,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @MaktiusHerrera: Faltan pocos dias @jpmontoya  #CarreraDeLasEstrellas!\U0001f601 \r\r*Por primera vez vere a mi \xeddolo!\U0001f602 http://t.co/MWVD3ivmJe',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Feb 17 00:17:01 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Verizon Team Penske driver. Race winner in F1, Indycar, NASCAR, CART,  and Grand-AM.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'jpmontoya.com',
#        u'expanded_url': u'http://www.jpmontoya.com/',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/Hyoe3wozQs'}]}},
#    u'favourites_count': 419,
#    u'follow_request_sent': False,
#    u'followers_count': 890628,
#    u'following': True,
#    u'friends_count': 193,
#    u'geo_enabled': False,
#    u'id': 21046818,
#    u'id_str': u'21046818',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 9555,
#    u'location': u'Miami',
#    u'name': u'Juan Pablo Montoya',
#    u'notifications': False,
#    u'profile_background_color': u'FFFFFF',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/516175288951009280/OFmI3XX4.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/516175288951009280/OFmI3XX4.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/21046818/1399337388',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/471243745262698496/F4dHBjBs_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/471243745262698496/F4dHBjBs_normal.jpeg',
#    u'profile_link_color': u'DD2E44',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'C30000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'jpmontoya',
#    u'statuses_count': 8093,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/Hyoe3wozQs',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 22:30:05 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/yNvCHr1U8C',
#      u'expanded_url': u'http://twitter.com/GeorgiaTech/status/537010293944365057/photo/1',
#      u'id': 537010292941545472,
#      u'id_str': u'537010292941545472',
#      u'indices': [115, 137],
#      u'media_url': u'http://pbs.twimg.com/media/B3PYBCeCYAABtuV.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PYBCeCYAABtuV.jpg',
#      u'sizes': {u'large': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/yNvCHr1U8C'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'c.gatech.edu/1AJolsv',
#      u'expanded_url': u'http://c.gatech.edu/1AJolsv',
#      u'indices': [90, 112],
#      u'url': u'http://t.co/GcVpM26jb5'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/yNvCHr1U8C',
#      u'expanded_url': u'http://twitter.com/GeorgiaTech/status/537010293944365057/photo/1',
#      u'id': 537010292941545472,
#      u'id_str': u'537010292941545472',
#      u'indices': [115, 137],
#      u'media_url': u'http://pbs.twimg.com/media/B3PYBCeCYAABtuV.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PYBCeCYAABtuV.jpg',
#      u'sizes': {u'large': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/yNvCHr1U8C'}]},
#   u'favorite_count': 7,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537010293944365057,
#   u'id_str': u'537010293944365057',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 10,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'Needles barely visible to human eye might treat a leading cause of blindness: glaucoma. | http://t.co/GcVpM26jb5 | http://t.co/yNvCHr1U8C',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Jan 16 19:16:40 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter account for the Georgia Institute of Technology.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'gatech.edu',
#        u'expanded_url': u'http://www.gatech.edu',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/Pj9BqU4Dcv'}]}},
#    u'favourites_count': 3164,
#    u'follow_request_sent': False,
#    u'followers_count': 37309,
#    u'following': True,
#    u'friends_count': 2161,
#    u'geo_enabled': True,
#    u'id': 19080617,
#    u'id_str': u'19080617',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 833,
#    u'location': u'Atlanta, GA',
#    u'name': u'Georgia Tech',
#    u'notifications': False,
#    u'profile_background_color': u'D3D7DB',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000082377035/1880c3af3168097a137be3231e4f042b.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000082377035/1880c3af3168097a137be3231e4f042b.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/19080617/1398986427',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000497979838/2b46896e5e13116a7361893810625d3e_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000497979838/2b46896e5e13116a7361893810625d3e_normal.jpeg',
#    u'profile_link_color': u'0D066A',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'FFFFFF',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'GeorgiaTech',
#    u'statuses_count': 7244,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/Pj9BqU4Dcv',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 22:30:03 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/3KsowJbNcg',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/537010282975879168/photo/1',
#      u'id': 536975185673351168,
#      u'id_str': u'536975185673351168',
#      u'indices': [80, 102],
#      u'media_url': u'http://pbs.twimg.com/media/B3O4FhtCcAAyORa.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3O4FhtCcAAyORa.jpg',
#      u'sizes': {u'large': {u'h': 512, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 300, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 170, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/3KsowJbNcg'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/1uShDCB',
#      u'expanded_url': u'http://bit.ly/1uShDCB',
#      u'indices': [57, 79],
#      u'url': u'http://t.co/SwdJ5v9Pfb'}],
#    u'user_mentions': [{u'id': 20444254,
#      u'id_str': u'20444254',
#      u'indices': [1, 11],
#      u'name': u'HoopsHype',
#      u'screen_name': u'hoopshype'},
#     {u'id': 88324102,
#      u'id_str': u'88324102',
#      u'indices': [14, 27],
#      u'name': u'David Alarc\xf3n',
#      u'screen_name': u'DAlarcon_NBA'},
#     {u'id': 78193153,
#      u'id_str': u'78193153',
#      u'indices': [44, 55],
#      u'name': u'Al Horford',
#      u'screen_name': u'Al_Horford'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/3KsowJbNcg',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/537010282975879168/photo/1',
#      u'id': 536975185673351168,
#      u'id_str': u'536975185673351168',
#      u'indices': [80, 102],
#      u'media_url': u'http://pbs.twimg.com/media/B3O4FhtCcAAyORa.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3O4FhtCcAAyORa.jpg',
#      u'sizes': {u'large': {u'h': 512, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 300, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 170, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/3KsowJbNcg'}]},
#   u'favorite_count': 11,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537010282975879168,
#   u'id_str': u'537010282975879168',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 10,
#   u'retweeted': False,
#   u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   u'text': u".@hoopshype's @DAlarcon_NBA catches up with @Al_Horford: http://t.co/SwdJ5v9Pfb http://t.co/3KsowJbNcg",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Nov 10 18:49:37 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter feed of the Atlanta Hawks!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'Hawks.com',
#        u'expanded_url': u'http://Hawks.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/46IXpwg4mo'}]}},
#    u'favourites_count': 280,
#    u'follow_request_sent': False,
#    u'followers_count': 252536,
#    u'following': True,
#    u'friends_count': 5902,
#    u'geo_enabled': True,
#    u'id': 17292143,
#    u'id_str': u'17292143',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 3247,
#    u'location': u'Philips Arena',
#    u'name': u'Atlanta Hawks',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17292143/1414604164',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ATLHawks',
#    u'statuses_count': 34372,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/46IXpwg4mo',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 22:06:34 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 19271784,
#      u'id_str': u'19271784',
#      u'indices': [3, 11],
#      u'name': u'Chad ',
#      u'screen_name': u'ChadWst'},
#     {u'id': 72878707,
#      u'id_str': u'72878707',
#      u'indices': [13, 29],
#      u'name': u'mettaworldpeace.com',
#      u'screen_name': u'MettaWorldPeace'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537004372958277633,
#   u'id_str': u'537004372958277633',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 2,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Nov 24 21:58:18 +0000 2014',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 72878707,
#       u'id_str': u'72878707',
#       u'indices': [0, 16],
#       u'name': u'mettaworldpeace.com',
#       u'screen_name': u'MettaWorldPeace'}]},
#    u'favorite_count': 4,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 537002294953668608,
#    u'id_str': u'537002294953668608',
#    u'in_reply_to_screen_name': u'MettaWorldPeace',
#    u'in_reply_to_status_id': 537001986369925120,
#    u'in_reply_to_status_id_str': u'537001986369925120',
#    u'in_reply_to_user_id': 72878707,
#    u'in_reply_to_user_id_str': u'72878707',
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 2,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"@MettaWorldPeace who's says you can't eat healthy on road. Nice!",
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Jan 21 02:28:47 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'IT Pro, science/space, punk rock, poker, DnB, sports, gym, health, juicing, dad. Honorable mention to beer. #SKINS #LAKERS #METS #HEELS -- MCSE, MCITP:EA',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'homegrownit.com',
#         u'expanded_url': u'http://www.homegrownit.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/BvFXx6FNjj'}]}},
#     u'favourites_count': 2687,
#     u'follow_request_sent': False,
#     u'followers_count': 370,
#     u'following': False,
#     u'friends_count': 1034,
#     u'geo_enabled': True,
#     u'id': 19271784,
#     u'id_str': u'19271784',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 8,
#     u'location': u'Charlotte, North Carolina',
#     u'name': u'Chad ',
#     u'notifications': False,
#     u'profile_background_color': u'1A1B1F',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/19271784/1391125163',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/456395119738880001/Pc1JX_LV_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/456395119738880001/Pc1JX_LV_normal.jpeg',
#     u'profile_link_color': u'030503',
#     u'profile_location': None,
#     u'profile_sidebar_border_color': u'181A1E',
#     u'profile_sidebar_fill_color': u'252429',
#     u'profile_text_color': u'666666',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'ChadWst',
#     u'statuses_count': 3952,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'url': u'http://t.co/BvFXx6FNjj',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u"RT @ChadWst: @MettaWorldPeace who's says you can't eat healthy on road. Nice!",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Sep 09 15:32:48 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'http://t.co/RvdZeQJCh0',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'Mettaworldpeace.com',
#        u'expanded_url': u'http://Mettaworldpeace.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/RvdZeQJCh0'}]},
#     u'url': {u'urls': [{u'display_url': u'mettaworldpeace.com',
#        u'expanded_url': u'http://mettaworldpeace.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/RDcqujQ7QI'}]}},
#    u'favourites_count': 1325,
#    u'follow_request_sent': False,
#    u'followers_count': 755129,
#    u'following': True,
#    u'friends_count': 2543,
#    u'geo_enabled': False,
#    u'id': 72878707,
#    u'id_str': u'72878707',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 7027,
#    u'location': u'mettaworldpeace.com',
#    u'name': u'mettaworldpeace.com',
#    u'notifications': False,
#    u'profile_background_color': u'1A1B1F',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000095336733/164a63cb6cbc8c9b3b89137db3bd8e85.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000095336733/164a63cb6cbc8c9b3b89137db3bd8e85.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/72878707/1416243832',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/534391480484261888/drbtZiTx_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/534391480484261888/drbtZiTx_normal.jpeg',
#    u'profile_link_color': u'2FC2EF',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'252429',
#    u'profile_text_color': u'666666',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'MettaWorldPeace',
#    u'statuses_count': 9455,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/RDcqujQ7QI',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 22:05:52 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 64977279,
#      u'id_str': u'64977279',
#      u'indices': [1, 16],
#      u'name': u'h a l e y',
#      u'screen_name': u'haleytweetweet'},
#     {u'id': 72878707,
#      u'id_str': u'72878707',
#      u'indices': [18, 34],
#      u'name': u'mettaworldpeace.com',
#      u'screen_name': u'MettaWorldPeace'}]},
#   u'favorite_count': 8,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 537004197367914496,
#   u'id_str': u'537004197367914496',
#   u'in_reply_to_screen_name': u'haleytweetweet',
#   u'in_reply_to_status_id': 537002373751640064,
#   u'in_reply_to_status_id_str': u'537002373751640064',
#   u'in_reply_to_user_id': 64977279,
#   u'in_reply_to_user_id_str': u'64977279',
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'\u201c@haleytweetweet: @MettaWorldPeace lol what is that?\u201d\n\nIt\'s called"Mint and Spinach pasta". Raw Mint and spinach. Beans etc;))))',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Sep 09 15:32:48 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'http://t.co/RvdZeQJCh0',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'Mettaworldpeace.com',
#        u'expanded_url': u'http://Mettaworldpeace.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/RvdZeQJCh0'}]},
#     u'url': {u'urls': [{u'display_url': u'mettaworldpeace.com',
#        u'expanded_url': u'http://mettaworldpeace.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/RDcqujQ7QI'}]}},
#    u'favourites_count': 1325,
#    u'follow_request_sent': False,
#    u'followers_count': 755129,
#    u'following': True,
#    u'friends_count': 2543,
#    u'geo_enabled': False,
#    u'id': 72878707,
#    u'id_str': u'72878707',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 7027,
#    u'location': u'mettaworldpeace.com',
#    u'name': u'mettaworldpeace.com',
#    u'notifications': False,
#    u'profile_background_color': u'1A1B1F',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000095336733/164a63cb6cbc8c9b3b89137db3bd8e85.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000095336733/164a63cb6cbc8c9b3b89137db3bd8e85.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/72878707/1416243832',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/534391480484261888/drbtZiTx_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/534391480484261888/drbtZiTx_normal.jpeg',
#    u'profile_link_color': u'2FC2EF',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'252429',
#    u'profile_text_color': u'666666',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'MettaWorldPeace',
#    u'statuses_count': 9455,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/RDcqujQ7QI',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 21:57:05 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/EvMevMSQ1e',
#      u'expanded_url': u'http://twitter.com/MettaWorldPeace/status/537001986369925120/photo/1',
#      u'id': 537001942849814528,
#      u'id_str': u'537001942849814528',
#      u'indices': [28, 50],
#      u'media_url': u'http://pbs.twimg.com/media/B3PQa_9CAAA78zQ.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PQa_9CAAA78zQ.jpg',
#      u'sizes': {u'large': {u'h': 768, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 450, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 255, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/EvMevMSQ1e'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/EvMevMSQ1e',
#      u'expanded_url': u'http://twitter.com/MettaWorldPeace/status/537001986369925120/photo/1',
#      u'id': 537001942849814528,
#      u'id_str': u'537001942849814528',
#      u'indices': [28, 50],
#      u'media_url': u'http://pbs.twimg.com/media/B3PQa_9CAAA78zQ.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PQa_9CAAA78zQ.jpg',
#      u'sizes': {u'large': {u'h': 768, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 450, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 255, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/EvMevMSQ1e'},
#     {u'display_url': u'pic.twitter.com/EvMevMSQ1e',
#      u'expanded_url': u'http://twitter.com/MettaWorldPeace/status/537001986369925120/photo/1',
#      u'id': 537001943642550272,
#      u'id_str': u'537001943642550272',
#      u'indices': [28, 50],
#      u'media_url': u'http://pbs.twimg.com/media/B3PQbC6CMAAVF7C.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3PQbC6CMAAVF7C.jpg',
#      u'sizes': {u'large': {u'h': 768, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 450, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 255, u'resize': u'fit', u'w': 340},
# ...
#       u'medium': {u'h': 450, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 255, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/gz7hTPQlc2'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/gz7hTPQlc2',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/536948490774253569/photo/1',
#      u'id': 536948470494420992,
#      u'id_str': u'536948470494420992',
#      u'indices': [43, 65],
#      u'media_url': u'http://pbs.twimg.com/media/B3Ofyf6CYAA6Ypx.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3Ofyf6CYAA6Ypx.jpg',
#      u'sizes': {u'large': {u'h': 768, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 450, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 255, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/gz7hTPQlc2'}]},
#   u'favorite_count': 24,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 536948490774253569,
#   u'id_str': u'536948490774253569',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 13,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u"Can you tell us who's wearing these shoes? http://t.co/gz7hTPQlc2",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Nov 10 18:49:37 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter feed of the Atlanta Hawks!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'Hawks.com',
#        u'expanded_url': u'http://Hawks.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/46IXpwg4mo'}]}},
#    u'favourites_count': 280,
#    u'follow_request_sent': False,
#    u'followers_count': 252536,
#    u'following': True,
#    u'friends_count': 5902,
#    u'geo_enabled': True,
#    u'id': 17292143,
#    u'id_str': u'17292143',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 3247,
#    u'location': u'Philips Arena',
#    u'name': u'Atlanta Hawks',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17292143/1414604164',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ATLHawks',
#    u'statuses_count': 34372,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/46IXpwg4mo',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 17:51:16 +0000 2014',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'c.gatech.edu/1y5LYoi',
#      u'expanded_url': u'http://c.gatech.edu/1y5LYoi',
#      u'indices': [112, 134],
#      u'url': u'http://t.co/lsx21Sa2vg'}],
#    u'user_mentions': []},
#   u'favorite_count': 9,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 536940124081487872,
#   u'id_str': u'536940124081487872',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 13,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u"Graduating more engineers should be a national priority. Op-Ed from Georgia Tech's College of Engineering Dean: http://t.co/lsx21Sa2vg",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Jan 16 19:16:40 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter account for the Georgia Institute of Technology.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'gatech.edu',
#        u'expanded_url': u'http://www.gatech.edu',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/Pj9BqU4Dcv'}]}},
#    u'favourites_count': 3164,
#    u'follow_request_sent': False,
#    u'followers_count': 37309,
#    u'following': True,
#    u'friends_count': 2161,
#    u'geo_enabled': True,
#    u'id': 19080617,
#    u'id_str': u'19080617',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 833,
#    u'location': u'Atlanta, GA',
#    u'name': u'Georgia Tech',
#    u'notifications': False,
#    u'profile_background_color': u'D3D7DB',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000082377035/1880c3af3168097a137be3231e4f042b.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000082377035/1880c3af3168097a137be3231e4f042b.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/19080617/1398986427',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000497979838/2b46896e5e13116a7361893810625d3e_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000497979838/2b46896e5e13116a7361893810625d3e_normal.jpeg',
#    u'profile_link_color': u'0D066A',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'FFFFFF',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'GeorgiaTech',
#    u'statuses_count': 7244,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/Pj9BqU4Dcv',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 16:28:59 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [100, 117],
#      u'text': u'HawksFanTakeover'}],
#    u'media': [{u'display_url': u'pic.twitter.com/IvyAkdDAtv',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/536919419210178560/photo/1',
#      u'id': 536919379124834304,
#      u'id_str': u'536919379124834304',
#      u'indices': [118, 140],
#      u'media_url': u'http://pbs.twimg.com/media/B3OFVKHCUAAA1VF.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3OFVKHCUAAA1VF.jpg',
#      u'sizes': {u'large': {u'h': 442, u'resize': u'fit', u'w': 760},
#       u'medium': {u'h': 348, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 197, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/IvyAkdDAtv'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'on.nba.com/1ApwnvF',
#      u'expanded_url': u'http://on.nba.com/1ApwnvF',
#      u'indices': [77, 99],
#      u'url': u'http://t.co/weMnpN9XNe'}],
#    u'user_mentions': [{u'id': 22016177,
#      u'id_str': u'22016177',
#      u'indices': [26, 37],
#      u'name': u'SportSouth',
#      u'screen_name': u'SportSouth'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/IvyAkdDAtv',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/536919419210178560/photo/1',
#      u'id': 536919379124834304,
#      u'id_str': u'536919379124834304',
#      u'indices': [118, 140],
#      u'media_url': u'http://pbs.twimg.com/media/B3OFVKHCUAAA1VF.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3OFVKHCUAAA1VF.jpg',
#      u'sizes': {u'large': {u'h': 442, u'resize': u'fit', u'w': 760},
#       u'medium': {u'h': 348, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 197, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/IvyAkdDAtv'}]},
#   u'favorite_count': 3,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 536919419210178560,
#   u'id_str': u'536919419210178560',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 7,
#   u'retweeted': False,
#   u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   u'text': u"Want to see your tweet on @SportSouth during our game tomorrow?\n\nHere's how: http://t.co/weMnpN9XNe #HawksFanTakeover http://t.co/IvyAkdDAtv",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Nov 10 18:49:37 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter feed of the Atlanta Hawks!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'Hawks.com',
#        u'expanded_url': u'http://Hawks.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/46IXpwg4mo'}]}},
#    u'favourites_count': 280,
#    u'follow_request_sent': False,
#    u'followers_count': 252536,
#    u'following': True,
#    u'friends_count': 5902,
#    u'geo_enabled': True,
#    u'id': 17292143,
#    u'id_str': u'17292143',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 3247,
#    u'location': u'Philips Arena',
#    u'name': u'Atlanta Hawks',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17292143/1414604164',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ATLHawks',
#    u'statuses_count': 34372,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/46IXpwg4mo',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Nov 24 15:10:19 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [89, 98], u'text': u'NBACares'},
#     {u'indices': [99, 109], u'text': u'HawksGive'}],
#    u'media': [{u'display_url': u'pic.twitter.com/oc9BMElzfU',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/536899621877194752/photo/1',
#      u'id': 536899547021070336,
#      u'id_str': u'536899547021070336',
#      u'indices': [110, 132],
#      u'media_url': u'http://pbs.twimg.com/media/B3NzSxxCUAA5GyY.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3NzSxxCUAA5GyY.jpg',
#      u'sizes': {u'large': {u'h': 382, u'resize': u'fit', u'w': 736},
#       u'medium': {u'h': 311, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 176, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/oc9BMElzfU'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'on.nba.com/1tpSQAi',
#      u'expanded_url': u'http://on.nba.com/1tpSQAi',
#      u'indices': [66, 88],
#      u'url': u'http://t.co/KHWaTcUcB2'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/oc9BMElzfU',
#      u'expanded_url': u'http://twitter.com/ATLHawks/status/536899621877194752/photo/1',
#      u'id': 536899547021070336,
#      u'id_str': u'536899547021070336',
#      u'indices': [110, 132],
#      u'media_url': u'http://pbs.twimg.com/media/B3NzSxxCUAA5GyY.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/B3NzSxxCUAA5GyY.jpg',
#      u'sizes': {u'large': {u'h': 382, u'resize': u'fit', u'w': 736},
#       u'medium': {u'h': 311, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 176, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/oc9BMElzfU'}]},
#   u'favorite_count': 24,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 536899621877194752,
#   u'id_str': u'536899621877194752',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 12,
#   u'retweeted': False,
#   u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   u'text': u'Surprise!\n\nWe took over a Kroger last week. Check out the photos: http://t.co/KHWaTcUcB2 #NBACares #HawksGive http://t.co/oc9BMElzfU',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Nov 10 18:49:37 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter feed of the Atlanta Hawks!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'Hawks.com',
#        u'expanded_url': u'http://Hawks.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/46IXpwg4mo'}]}},
#    u'favourites_count': 280,
#    u'follow_request_sent': False,
#    u'followers_count': 252536,
#    u'following': True,
#    u'friends_count': 5902,
#    u'geo_enabled': True,
#    u'id': 17292143,
#    u'id_str': u'17292143',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 3247,
#    u'location': u'Philips Arena',
#    u'name': u'Atlanta Hawks',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/535860507463266304/nrsNgsGi.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17292143/1414604164',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/489157282609897473/grv1aXcZ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_location': None,
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ATLHawks',
#    u'statuses_count': 34372,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/46IXpwg4mo',
#    u'utc_offset': -18000,
#    u'verified': True}}]

# %%
# -*- coding: utf-8 -*-
"""
Yelp API v2.0 code sample.

This program demonstrates the capability of the Yelp API version 2.0
by using the Search API to query for businesses by a search term and location,
and the Business API to query additional information about the top result
from the search query.

Please refer to http://www.yelp.com/developers/documentation for the API documentation.

This program requires the Python oauth2 library, which you can install via:
`pip install -r requirements.txt`.

Sample usage of the program:
`python sample.py --term="bars" --location="San Francisco, CA"`
"""
import argparse
import json
import pprint
import sys
import urllib
import urllib2

import oauth2


API_HOST = 'api.twitter.com'
SEARCH_PATH = '/1.1/users/search/'

# OAuth credential placeholders that must be filled in by users.
import oauth2 as oauth
import time

def request(host, path, url_params=None):
    """Prepares OAuth authentication and sends the request to the API.

    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        url_params (dict): An optional set of query parameters in the request.

    Returns:
        dict: The JSON response from the request.

    Raises:
        urllib2.HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = 'https://{0}{1}?'.format(host, path)

    consumer = oauth2.Consumer(CONSUMER_KEY, CONSUMER_SECRET)
    oauth_request = oauth2.Request(method="GET", url=url, parameters=url_params)

    oauth_request.update(
        {
            'oauth_nonce': oauth2.generate_nonce(),
            'oauth_timestamp': oauth2.generate_timestamp(),
            'oauth_token': TOKEN,
            'oauth_consumer_key': CONSUMER_KEY
        }
    )
    token = oauth2.Token(TOKEN, TOKEN_SECRET)
    oauth_request.sign_request(oauth2.SignatureMethod_HMAC_SHA1(), consumer, token)
    signed_url = oauth_request.to_url()
    signed_url = 'https://api.twitter.com/1.1/users/search.json?count=3&page=1&oauth_consumer_key=ZanES4cy8hufvy2yjTLFG8tbO&oauth_nonce=0368e8ceddec51fe89a696ab67cf42e9&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1416888677&oauth_token=2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU&oauth_version=1.0&q=Twitter'
    print signed_url
    
    print 'Querying {0} ...'.format(url)

    conn = urllib2.urlopen(signed_url, None)
    try:
        response = json.loads(conn.read())
    finally:
        conn.close()

    return response

def searchUser(term):
    """Query the Search API by a search term and location.

    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.

    Returns:
        dict: The JSON response from the request.
    """
    # https://api.twitter.com/1.1/users/search.json?q=&page=1&count=3
    url_params = {
        'q': term.replace(' ', '+'),
        'page': 1,
        'count': 1
        
        #'limit': SEARCH_LIMIT,
        #'sort':1,
        #'category_filter':'dimsum'
    }
    return request(API_HOST, SEARCH_PATH, url_params=url_params)


def search(term, location):
    """Query the Search API by a search term and location.

    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.

    Returns:
        dict: The JSON response from the request.
    """
    
    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'sort':1,
        'category_filter':'dimsum'
    }
    return request(API_HOST, SEARCH_PATH, url_params=url_params)

def get_business(business_id):
    """Query the Business API by a business ID.

    Args:
        business_id (str): The ID of the business to query.

    Returns:
        dict: The JSON response from the request.
    """
    business_path = BUSINESS_PATH + business_id

    return request(API_HOST, business_path)

# %%
searchUser("kobe")
# Out:
# https://api.twitter.com/1.1/users/search.json?count=3&page=1&oauth_consumer_key=ZanES4cy8hufvy2yjTLFG8tbO&oauth_nonce=0368e8ceddec51fe89a696ab67cf42e9&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1416888677&oauth_token=2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU&oauth_version=1.0&q=Twitter
# Querying https://api.twitter.com/1.1/users/search/? ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-107-b5e046332840> in <module>()
# ----> 1 searchUser("kobe")
#
# <ipython-input-106-ff9ee7a9fbb5> in searchUser(term)
#      97         #'category_filter':'dimsum'
#      98     }
# ---> 99     return request(API_HOST, SEARCH_PATH, url_params=url_params)
#     100
#     101
#
# <ipython-input-106-ff9ee7a9fbb5> in request(host, path, url_params)
#      69     print 'Querying {0} ...'.format(url)
#      70
# ---> 71     conn = urllib2.urlopen(signed_url, None)
#      72     try:
#      73         response = json.loads(conn.read())
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout)
#     125     if _opener is None:
#     126         _opener = build_opener()
# --> 127     return _opener.open(url, data, timeout)
#     128
#     129 def install_opener(opener):
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     408         for processor in self.process_response.get(protocol, []):
#     409             meth = getattr(processor, meth_name)
# --> 410             response = meth(req, response)
#     411
#     412         return response
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     521         if not (200 <= code < 300):
#     522             response = self.parent.error(
# --> 523                 'http', request, response, code, msg, hdrs)
#     524
#     525         return response
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     446         if http_err:
#     447             args = (dict, 'default', 'http_error_default') + orig_args
# --> 448             return self._call_chain(*args)
#     449
#     450 # XXX probably also want an abstract factory that knows when it makes
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     380             func = getattr(handler, meth_name)
#     381
# --> 382             result = func(*args)
#     383             if result is not None:
#     384                 return result
#
# /Users/tianlan/anaconda/python.app/Contents/lib/python2.7/urllib2.pyc in http_error_default(self, req, fp, code, msg, hdrs)
#     529 class HTTPDefaultErrorHandler(BaseHandler):
#     530     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 531         raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
#     532
#     533 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
CONSUMER_KEY = "ZanES4cy8hufvy2yjTLFG8tbO"
CONSUMER_SECRET = "uSbXql55opsnhzGyUlRngp72ZrjjTDNrtkXRHJZ2nTmJJCQ5Mi"
key = "2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU"
secret = "I7doox0PWs22EUMIqFPnk7SqMDFydethoOOR83Wif954f"


import oauth2 as oauth
import time

# Set the API endpoint 
url = "http://example.com/photos"

# Set the base oauth_* parameters along with any other parameters required
# for the API call.
params = {
    'oauth_version': "1.0",
    'oauth_nonce': oauth.generate_nonce(),
    'oauth_timestamp': int(time.time())
    #'user': 'joestump',
    #'photoid': 555555555555
}

# Set up instances of our Token and Consumer. The Consumer.key and 
# Consumer.secret are given to you by the API provider. The Token.key and
# Token.secret is given to you after a three-legged authentication.
token = oauth.Token(key=key, secret=secret)
consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)

# Set our token/key parameters
params['oauth_token'] = token.key
params['oauth_consumer_key'] = consumer.key

# Create our request. Change method, etc. accordingly.
req = oauth.Request(method="GET", url=url, parameters=params)

# Sign the request.
signature_method = oauth.SignatureMethod_HMAC_SHA1()
req.sign_request(signature_method, consumer, token)

# %%
# Out:
# oauth2.Request

# %%
# Create your consumer with the proper key/secret.
#consumer = oauth.Consumer(key="your-twitter-consumer-key", 
#    secret="your-twitter-consumer-secret")

# Request token URL for Twitter.
request_token_url = "http://twitter.com/oauth/request_token"

# Create our client.
client = oauth.Client(consumer)

# The OAuth Client request works just like httplib2 for the most part.
resp, content = client.request(request_token_url, "GET")
#print resp
print content
# Out:
# Failed to validate oauth signature and token

# %%
def oauth_req(url, key, secret, http_method="GET", post_body=None, http_headers=None):
    consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
    token = oauth.Token(key=key, secret=secret)
    client = oauth.Client(consumer, token)
    resp, content = client.request( url, method=http_method, body=post_body, headers=http_headers, force_auth_header=True )
    return content 
home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', key, secret )
# Out:
#   File "<ipython-input-66-4abf38a4604d>", line 2
#     consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
#     ^
# SyntaxError: invalid syntax

# %%
import oauth2 as oauth
import urllib2 as urllib


# See assignment1.html instructions or README for how to get these credentials

api_key = "ZanES4cy8hufvy2yjTLFG8tbO"
api_secret = "uSbXql55opsnhzGyUlRngp72ZrjjTDNrtkXRHJZ2nTmJJCQ5Mi"
access_token_key = "2268307190-H2eYVAJ3QrrMyuV9nc4ri44pCyZsol0ricXdniU"
access_token_secret = "I7doox0PWs22EUMIqFPnk7SqMDFydethoOOR83Wif954f"

_debug = 0

oauth_token    = oauth.Token(key=access_token_key, secret=access_token_secret)
oauth_consumer = oauth.Consumer(key=api_key, secret=api_secret)

signature_method_hmac_sha1 = oauth.SignatureMethod_HMAC_SHA1()

http_method = "GET"


http_handler  = urllib.HTTPHandler(debuglevel=_debug)
https_handler = urllib.HTTPSHandler(debuglevel=_debug)

'''
Construct, sign, and open a twitter request
using the hard-coded credentials above.
'''
def twitterreq(url, method, parameters):
  req = oauth.Request.from_consumer_and_token(oauth_consumer,
                                             token=oauth_token,
                                             http_method=http_method,
                                             http_url=url, 
                                             parameters=parameters)

  req.sign_request(signature_method_hmac_sha1, oauth_consumer, oauth_token)

  headers = req.to_header()

  if http_method == "POST":
    encoded_post_data = req.to_postdata()
  else:
    encoded_post_data = None
    url = req.to_url()

  opener = urllib.OpenerDirector()
  opener.add_handler(http_handler)
  opener.add_handler(https_handler)

  response = opener.open(url, encoded_post_data)

  return response

def fetchsamples():
  url = "https://api.twitter.com/1.1/users/search.json?q=Twitter%20API&page=1&count=3"
  parameters = []
  response = twitterreq(url, "GET", parameters)
  #for line in response[0:20]:
  #  print line.strip()
  return response

# %%
out = fetchsamples()

# %%
type(out)
# Out:
# instance

# %%
out.readline()
# Out:
# '{"errors":[{"code":25,"message":"Query parameters are missing."}]}'
